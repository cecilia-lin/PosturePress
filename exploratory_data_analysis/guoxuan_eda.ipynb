# %%
import pandas as pd
import numpy as np
import glob
import os
import sys

def getting_metaInfo_experiment_i(directory_path):
    return pd.read_csv(os.path.join(directory_path, "experiment-i/subject-info-i.csv"))


def getting_metaInfo_experiment_ii(directory_path):
    return pd.read_csv(
        os.path.join(directory_path, "experiment-ii/subject-info-ii.csv")
    )

def reading_experiment_i_data(directory_path):
    subject_posture_data = {}
    subject_folders = sorted(glob.glob(os.path.join(directory_path, "S*")))  # e.g., "S1", "S2", etc.

    for subject in subject_folders:
        subject_id = os.path.basename(subject)
        subject_posture_data[subject_id] = {}

        txt_files = sorted(glob.glob(os.path.join(subject, "*.txt")))

        for txt_file in txt_files:
            posture_id = os.path.splitext(os.path.basename(txt_file))[0]  # Extract posture name (e.g., "1", "2")

            # Manually read and clean the file
            cleaned_data = []
            with open(txt_file, "r") as f:
                for line in f:
                    line = line.strip()
                    if line and not any(c.isalpha() for c in line):  # Ignore empty lines and non-numeric separators
                        cleaned_data.append([float(x) for x in line.split("\t")])  # Convert valid numeric data

            # Convert to NumPy array
            data = np.array(cleaned_data)

            # **Convert raw values (0-1000) to mmHg (0-100)**
            data = data * 0.1  # Apply conversion factor

            # Compute the number of frames
            total_values = data.size
            num_frames = total_values // (32 * 64)

            frames = data[: num_frames * 64 * 32].reshape(num_frames, 64, 32)
            frames = frames[2:]  # Only start at frame 3

            # Store frames under subject -> posture
            subject_posture_data[subject_id][posture_id] = frames

    return subject_posture_data


def reading_experiment_ii_data(directory_path):
    subject_posture_data = {}
    subject_folders = sorted(glob.glob(os.path.join(directory_path, "S*")))  # e.g., "S1", "S2", etc.

    for subject in subject_folders:
        subject_id = os.path.basename(subject)
        subject_posture_data[subject_id] = {}

        # open and process each folder in the subject folder
        for mat_kind in os.listdir(subject):

            mat_name = os.path.basename(mat_kind)

            subject_posture_data[subject_id][mat_name] = {}

            for posture in os.listdir(os.path.join(subject, mat_kind)):
                posture_id = os.path.splitext(os.path.basename(posture))[0]  # Extract posture name (e.g., "1", "2")

                print(f"Processing {subject_id} - {mat_name} - {posture_id}")

                # Manually read and clean the file
                cleaned_data = []
                print(os.path.join(subject, mat_kind, posture))
                with open(os.path.join(subject, mat_kind, posture), "r") as f:
                    for line in f:
                        line = line.strip()
                        if line and not any(c.isalpha() for c in line):  # Ignore empty lines and non-numeric separators
                            cleaned_data.extend([float(x) for x in line.split(" ")])  # Concatenate all numbers into a single sequence
                
                data = np.array(cleaned_data)
                subject_posture_data[subject_id][mat_name][posture_id] = data

    return subject_posture_data

test = reading_experiment_ii_data("/Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii")
# Out:
# Processing S1 - Air_Mat - Matrix_Air_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B8.txt
# Processing S1 - Air_Mat - Matrix_Air_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B9.txt
# Processing S1 - Air_Mat - Matrix_Air_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_F3.txt
# Processing S1 - Air_Mat - Matrix_Air_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_F2.txt
# Processing S1 - Air_Mat - Matrix_Air_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_F1.txt
# Processing S1 - Air_Mat - Matrix_Air_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_F5.txt
# Processing S1 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_F4.txt
# Processing S1 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_F6.txt
# Processing S1 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_F7.txt
# Processing S1 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_E6.txt
# Processing S1 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_D2.txt
# Processing S1 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_D3.txt
# Processing S1 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_D1.txt
# Processing S1 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_E5.txt
# Processing S1 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_E4.txt
# Processing S1 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_E1.txt
# Processing S1 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_E3.txt
# Processing S1 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B10.txt
# Processing S1 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_E2.txt
# Processing S1 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B1.txt
# Processing S1 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B2.txt
# Processing S1 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B3.txt
# Processing S1 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B7.txt
# Processing S1 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_C3.txt
# Processing S1 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_C2.txt
# Processing S1 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B6.txt
# Processing S1 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B4.txt
# Processing S1 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_B5.txt
# Processing S1 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Air_Mat/Matrix_Air_C1.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B7.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_C3.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_E4.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_D1.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_E5.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_D3.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_E6.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_D2.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_E2.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_E3.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_E1.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_F1.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_F2.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_F3.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_F7.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_F6.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_F4.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_F5.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B9.txt
# Processing S1 - Sponge_Mat - Matrix_Sponge_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S1/Sponge_Mat/Matrix_Sponge_B8.txt
# Processing S2 - Air_Mat - Matrix_Air_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B8.txt
# Processing S2 - Air_Mat - Matrix_Air_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B9.txt
# Processing S2 - Air_Mat - Matrix_Air_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_F3.txt
# Processing S2 - Air_Mat - Matrix_Air_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_F2.txt
# Processing S2 - Air_Mat - Matrix_Air_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_F1.txt
# Processing S2 - Air_Mat - Matrix_Air_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_F5.txt
# Processing S2 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_F4.txt
# Processing S2 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_F6.txt
# Processing S2 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_F7.txt
# Processing S2 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_E6.txt
# Processing S2 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_D2.txt
# Processing S2 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_D3.txt
# Processing S2 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_D1.txt
# Processing S2 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_E5.txt
# Processing S2 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_E4.txt
# Processing S2 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_E1.txt
# Processing S2 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_E3.txt
# Processing S2 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B10.txt
# Processing S2 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_E2.txt
# Processing S2 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B1.txt
# Processing S2 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B2.txt
# Processing S2 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B3.txt
# Processing S2 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B7.txt
# Processing S2 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_C3.txt
# Processing S2 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_C2.txt
# Processing S2 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B6.txt
# Processing S2 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B4.txt
# Processing S2 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_B5.txt
# Processing S2 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Air_Mat/Matrix_Air_C1.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B7.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_C3.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_E4.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_D1.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_E5.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_D3.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_E6.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_D2.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_E2.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_E3.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_E1.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_F1.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_F2.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_F3.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_F7.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_F6.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_F4.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_F5.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B9.txt
# Processing S2 - Sponge_Mat - Matrix_Sponge_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S2/Sponge_Mat/Matrix_Sponge_B8.txt
# Processing S3 - Air_Mat - Matrix_Air_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B8.txt
# Processing S3 - Air_Mat - Matrix_Air_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B9.txt
# Processing S3 - Air_Mat - Matrix_Air_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_F3.txt
# Processing S3 - Air_Mat - Matrix_Air_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_F2.txt
# Processing S3 - Air_Mat - Matrix_Air_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_F1.txt
# Processing S3 - Air_Mat - Matrix_Air_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_F5.txt
# Processing S3 - Air_Mat - Matrix_Air_G1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_G1.txt
# Processing S3 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_F4.txt
# Processing S3 - Air_Mat - Matrix_Air_G2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_G2.txt
# Processing S3 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_F6.txt
# Processing S3 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_F7.txt
# Processing S3 - Air_Mat - Matrix_Air_G3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_G3.txt
# Processing S3 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_E6.txt
# Processing S3 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_D2.txt
# Processing S3 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_D3.txt
# Processing S3 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_D1.txt
# Processing S3 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_E5.txt
# Processing S3 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_E4.txt
# Processing S3 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_E1.txt
# Processing S3 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_E3.txt
# Processing S3 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B10.txt
# Processing S3 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_E2.txt
# Processing S3 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B1.txt
# Processing S3 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B2.txt
# Processing S3 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B3.txt
# Processing S3 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B7.txt
# Processing S3 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_C3.txt
# Processing S3 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_C2.txt
# Processing S3 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B6.txt
# Processing S3 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B4.txt
# Processing S3 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_B5.txt
# Processing S3 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Air_Mat/Matrix_Air_C1.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B7.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_C3.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_E4.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_D1.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_E5.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_D3.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_E6.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_D2.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_E2.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_E3.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_E1.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_F1.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_F2.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_F3.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_F7.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_F6.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_F4.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_F5.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B9.txt
# Processing S3 - Sponge_Mat - Matrix_Sponge_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S3/Sponge_Mat/Matrix_Sponge_B8.txt
# Processing S4 - Air_Mat - Matrix_Air_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B8.txt
# Processing S4 - Air_Mat - Matrix_Air_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B9.txt
# Processing S4 - Air_Mat - Matrix_Air_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_F3.txt
# Processing S4 - Air_Mat - Matrix_Air_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_F2.txt
# Processing S4 - Air_Mat - Matrix_Air_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_F1.txt
# Processing S4 - Air_Mat - Matrix_Air_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_F5.txt
# Processing S4 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_F4.txt
# Processing S4 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_F6.txt
# Processing S4 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_F7.txt
# Processing S4 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_E6.txt
# Processing S4 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_D2.txt
# Processing S4 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_D3.txt
# Processing S4 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_D1.txt
# Processing S4 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_E5.txt
# Processing S4 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_E4.txt
# Processing S4 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_E1.txt
# Processing S4 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_E3.txt
# Processing S4 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B10.txt
# Processing S4 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_E2.txt
# Processing S4 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B1.txt
# Processing S4 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B2.txt
# Processing S4 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B3.txt
# Processing S4 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B7.txt
# Processing S4 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_C3.txt
# Processing S4 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_C2.txt
# Processing S4 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B6.txt
# Processing S4 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B4.txt
# Processing S4 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_B5.txt
# Processing S4 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Air_Mat/Matrix_Air_C1.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B7.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_C3.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_E4.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_D1.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_E5.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_D3.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_E6.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_D2.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_E2.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_E3.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_E1.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_F1.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_F2.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_F3.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_F7.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_F6.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_F4.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_F5.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B9.txt
# Processing S4 - Sponge_Mat - Matrix_Sponge_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S4/Sponge_Mat/Matrix_Sponge_B8.txt
# Processing S5 - Air_Mat - Matrix_Air_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B8.txt
# Processing S5 - Air_Mat - Matrix_Air_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B9.txt
# Processing S5 - Air_Mat - Matrix_Air_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_F3.txt
# Processing S5 - Air_Mat - Matrix_Air_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_F2.txt
# Processing S5 - Air_Mat - Matrix_Air_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_F1.txt
# Processing S5 - Air_Mat - Matrix_Air_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_F5.txt
# Processing S5 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_F4.txt
# Processing S5 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_F6.txt
# Processing S5 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_F7.txt
# Processing S5 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_E6.txt
# Processing S5 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_D2.txt
# Processing S5 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_D3.txt
# Processing S5 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_D1.txt
# Processing S5 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_E5.txt
# Processing S5 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_E4.txt
# Processing S5 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_E1.txt
# Processing S5 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_E3.txt
# Processing S5 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B10.txt
# Processing S5 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_E2.txt
# Processing S5 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B1.txt
# Processing S5 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B2.txt
# Processing S5 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B3.txt
# Processing S5 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B7.txt
# Processing S5 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_C3.txt
# Processing S5 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_C2.txt
# Processing S5 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B6.txt
# Processing S5 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B4.txt
# Processing S5 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_B5.txt
# Processing S5 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Air_Mat/Matrix_Air_C1.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B7.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_C3.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_E4.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_D1.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_E5.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_D3.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_E6.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_D2.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_E2.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_E3.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_E1.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_F1.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_F2.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_F3.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_F7.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_F6.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_F4.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_F5.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B9.txt
# Processing S5 - Sponge_Mat - Matrix_Sponge_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S5/Sponge_Mat/Matrix_Sponge_B8.txt
# Processing S6 - Air_Mat - Matrix_Air_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B8.txt
# Processing S6 - Air_Mat - Matrix_Air_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B9.txt
# Processing S6 - Air_Mat - Matrix_Air_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_F3.txt
# Processing S6 - Air_Mat - Matrix_Air_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_F2.txt
# Processing S6 - Air_Mat - Matrix_Air_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_F1.txt
# Processing S6 - Air_Mat - Matrix_Air_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_F5.txt
# Processing S6 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_F4.txt
# Processing S6 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_F6.txt
# Processing S6 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_F7.txt
# Processing S6 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_E6.txt
# Processing S6 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_D2.txt
# Processing S6 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_D3.txt
# Processing S6 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_D1.txt
# Processing S6 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_E5.txt
# Processing S6 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_E4.txt
# Processing S6 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_E1.txt
# Processing S6 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_E3.txt
# Processing S6 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B10.txt
# Processing S6 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_E2.txt
# Processing S6 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B1.txt
# Processing S6 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B2.txt
# Processing S6 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B3.txt
# Processing S6 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B7.txt
# Processing S6 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_C3.txt
# Processing S6 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_C2.txt
# Processing S6 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B6.txt
# Processing S6 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B4.txt
# Processing S6 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_B5.txt
# Processing S6 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Air_Mat/Matrix_Air_C1.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S6/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S6 - Sponge_Mat - Matrix_Sponge_B7
# ...
# Processing S7 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_F4.txt
# Processing S7 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_F6.txt
# Processing S7 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_F7.txt
# Processing S7 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_E6.txt
# Processing S7 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_D2.txt
# Processing S7 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_D3.txt
# Processing S7 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_D1.txt
# Processing S7 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_E5.txt
# Processing S7 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_E4.txt
# Processing S7 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_E1.txt
# Processing S7 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_E3.txt
# Processing S7 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B10.txt
# Processing S7 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_E2.txt
# Processing S7 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B1.txt
# Processing S7 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B2.txt
# Processing S7 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B3.txt
# Processing S7 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B7.txt
# Processing S7 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_C3.txt
# Processing S7 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_C2.txt
# Processing S7 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B6.txt
# Processing S7 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B4.txt
# Processing S7 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_B5.txt
# Processing S7 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Air_Mat/Matrix_Air_C1.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B7.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_C3.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_E4.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_D1.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_E5.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_D3.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_E6.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_D2.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_E2.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_E3.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_E1.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_F1.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_F2.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_F3.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_F7.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_F6.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_F4.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_F5.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B9.txt
# Processing S7 - Sponge_Mat - Matrix_Sponge_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S7/Sponge_Mat/Matrix_Sponge_B8.txt
# Processing S8 - Air_Mat - Matrix_Air_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B8.txt
# Processing S8 - Air_Mat - Matrix_Air_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B9.txt
# Processing S8 - Air_Mat - Matrix_Air_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_F3.txt
# Processing S8 - Air_Mat - Matrix_Air_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_F2.txt
# Processing S8 - Air_Mat - Matrix_Air_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_F1.txt
# Processing S8 - Air_Mat - Matrix_Air_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_F5.txt
# Processing S8 - Air_Mat - Matrix_Air_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_F4.txt
# Processing S8 - Air_Mat - Matrix_Air_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_F6.txt
# Processing S8 - Air_Mat - Matrix_Air_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_F7.txt
# Processing S8 - Air_Mat - Matrix_Air_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_E6.txt
# Processing S8 - Air_Mat - Matrix_Air_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_D2.txt
# Processing S8 - Air_Mat - Matrix_Air_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_D3.txt
# Processing S8 - Air_Mat - Matrix_Air_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_D1.txt
# Processing S8 - Air_Mat - Matrix_Air_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_E5.txt
# Processing S8 - Air_Mat - Matrix_Air_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_E4.txt
# Processing S8 - Air_Mat - Matrix_Air_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_E1.txt
# Processing S8 - Air_Mat - Matrix_Air_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_E3.txt
# Processing S8 - Air_Mat - Matrix_Air_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B10.txt
# Processing S8 - Air_Mat - Matrix_Air_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_E2.txt
# Processing S8 - Air_Mat - Matrix_Air_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B1.txt
# Processing S8 - Air_Mat - Matrix_Air_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B2.txt
# Processing S8 - Air_Mat - Matrix_Air_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B3.txt
# Processing S8 - Air_Mat - Matrix_Air_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B7.txt
# Processing S8 - Air_Mat - Matrix_Air_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_C3.txt
# Processing S8 - Air_Mat - Matrix_Air_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_C2.txt
# Processing S8 - Air_Mat - Matrix_Air_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B6.txt
# Processing S8 - Air_Mat - Matrix_Air_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B4.txt
# Processing S8 - Air_Mat - Matrix_Air_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_B5.txt
# Processing S8 - Air_Mat - Matrix_Air_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Air_Mat/Matrix_Air_C1.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B3.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B2.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B10
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B10.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B1.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B5.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_C1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_C1.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B4.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_C2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_C2.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B6.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B7.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_C3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_C3.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_E4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_E4.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_D1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_D1.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_E5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_E5.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_D3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_D3.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_E6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_E6.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_D2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_D2.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_E2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_E2.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_E3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_E3.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_E1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_E1.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_F1
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_F1.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_F2
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_F2.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_F3
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_F3.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_F7
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_F7.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_F6
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_F6.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_F4
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_F4.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_F5
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_F5.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B9
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B9.txt
# Processing S8 - Sponge_Mat - Matrix_Sponge_B8
# /Users/guoxuanxu/Documents/local_repo/PosturePress/data/experiment-ii/S8/Sponge_Mat/Matrix_Sponge_B8.txt

# %% [markdown]
# ## Explore Data set

# %%
# process the subject info of the participants in experiment i


participants_i_meta_info = getting_metaInfo_experiment_i('/Users/guoxuanxu/Documents/local_repo/PosturePress/data')
participants_ii_meta_info = getting_metaInfo_experiment_ii('/Users/guoxuanxu/Documents/local_repo/PosturePress/data')

# %%
participants_ii_meta_info
# Out:
#    Subject-Number  Age  Height/cm  Weight/kg
# 0               1   19        175         87
# 1               2   23        183         85
# 2               3   23        183        100
# 3               4   24        172         66
# 4               5   27        179         96
# 5               6   27        186         63
# 6               7   30        174         74
# 7               8   30        174         79
# 8              12   33        170         78

# %%
test
# Out:
# {'S1': {'Air_Mat': {'Matrix_Air_B8': array([44., 43., 48., ..., 58., 53., 50.]),
#    'Matrix_Air_B9': array([45., 42., 44., ..., 43., 47., 56.]),
#    'Matrix_Air_F3': array([42., 44., 41., ..., 49., 49., 59.]),
#    'Matrix_Air_F2': array([48., 44., 44., ..., 49., 51., 57.]),
#    'Matrix_Air_F1': array([44., 43., 46., ..., 49., 56., 61.]),
#    'Matrix_Air_F5': array([43., 44., 48., ..., 50., 48., 57.]),
#    'Matrix_Air_F4': array([43., 42., 43., ..., 50., 50., 58.]),
#    'Matrix_Air_F6': array([47., 43., 45., ..., 55., 52., 58.]),
#    'Matrix_Air_F7': array([55., 48., 49., ..., 47., 50., 56.]),
#    'Matrix_Air_E6': array([44., 43., 44., ..., 59., 55., 54.]),
#    'Matrix_Air_D2': array([44., 44., 44., ..., 47., 46., 48.]),
#    'Matrix_Air_D3': array([43., 44., 44., ..., 49., 49., 48.]),
#    'Matrix_Air_D1': array([52., 44., 43., ..., 89., 72., 65.]),
#    'Matrix_Air_E5': array([45., 44., 42., ..., 49., 56., 57.]),
#    'Matrix_Air_E4': array([43., 43., 44., ..., 48., 51., 56.]),
#    'Matrix_Air_E1': array([44., 43., 44., ..., 49., 52., 58.]),
#    'Matrix_Air_E3': array([42., 45., 44., ..., 48., 48., 52.]),
#    'Matrix_Air_B10': array([44., 44., 44., ..., 46., 47., 54.]),
#    'Matrix_Air_E2': array([44., 44., 44., ..., 52., 50., 61.]),
#    'Matrix_Air_B1': array([44., 44., 50., ..., 48., 47., 57.]),
#    'Matrix_Air_B2': array([44., 43., 42., ..., 46., 48., 51.]),
#    'Matrix_Air_B3': array([44., 48., 44., ..., 52., 51., 55.]),
#    'Matrix_Air_B7': array([43., 43., 44., ..., 45., 47., 51.]),
#    'Matrix_Air_C3': array([50., 43., 43., ..., 45., 50., 58.]),
#    'Matrix_Air_C2': array([46., 44., 43., ..., 53., 49., 55.]),
#    'Matrix_Air_B6': array([43., 43., 44., ..., 47., 48., 53.]),
#    'Matrix_Air_B4': array([43., 42., 44., ..., 52., 49., 51.]),
#    'Matrix_Air_B5': array([61., 56., 60., ..., 59., 65., 53.]),
#    'Matrix_Air_C1': array([49., 52., 50., ..., 50., 47., 50.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([42., 43., 45., ..., 50., 55., 50.]),
#    'Matrix_Sponge_B2': array([43., 43., 42., ..., 44., 44., 44.]),
#    'Matrix_Sponge_B10': array([42., 43., 44., ..., 44., 44., 49.]),
#    'Matrix_Sponge_B1': array([45., 46., 55., ..., 47., 44., 45.]),
#    'Matrix_Sponge_B5': array([44., 49., 47., ..., 57., 52., 46.]),
#    'Matrix_Sponge_C1': array([43., 42., 47., ..., 44., 46., 46.]),
#    'Matrix_Sponge_B4': array([42., 43., 46., ..., 44., 46., 48.]),
#    'Matrix_Sponge_C2': array([43., 43., 47., ..., 42., 44., 47.]),
#    'Matrix_Sponge_B6': array([43., 43., 44., ..., 44., 47., 47.]),
#    'Matrix_Sponge_B7': array([47., 43., 44., ..., 44., 46., 45.]),
#    'Matrix_Sponge_C3': array([46., 43., 44., ..., 43., 44., 46.]),
#    'Matrix_Sponge_E4': array([42., 43., 45., ..., 54., 50., 47.]),
#    'Matrix_Sponge_D1': array([44., 43., 44., ..., 78., 76., 66.]),
#    'Matrix_Sponge_E5': array([43., 44., 44., ..., 44., 44., 46.]),
#    'Matrix_Sponge_D3': array([45., 42., 45., ..., 46., 47., 51.]),
#    'Matrix_Sponge_E6': array([43., 43., 46., ..., 46., 45., 49.]),
#    'Matrix_Sponge_D2': array([44., 47., 44., ..., 45., 47., 53.]),
#    'Matrix_Sponge_E2': array([42., 43., 45., ..., 44., 43., 48.]),
#    'Matrix_Sponge_E3': array([43., 43., 43., ..., 50., 45., 47.]),
#    'Matrix_Sponge_E1': array([42., 42., 44., ..., 44., 48., 48.]),
#    'Matrix_Sponge_F1': array([42., 43., 41., ..., 45., 44., 50.]),
#    'Matrix_Sponge_F2': array([44., 48., 44., ..., 44., 44., 49.]),
#    'Matrix_Sponge_F3': array([44., 42., 44., ..., 44., 45., 49.]),
#    'Matrix_Sponge_F7': array([47., 43., 46., ..., 47., 45., 53.]),
#    'Matrix_Sponge_F6': array([42., 43., 44., ..., 44., 44., 53.]),
#    'Matrix_Sponge_F4': array([44., 42., 44., ..., 44., 45., 50.]),
#    'Matrix_Sponge_F5': array([42., 43., 47., ..., 44., 43., 51.]),
#    'Matrix_Sponge_B9': array([42., 47., 45., ..., 46., 45., 44.]),
#    'Matrix_Sponge_B8': array([44., 44., 44., ..., 49., 44., 50.])}},
#  'S2': {'Air_Mat': {'Matrix_Air_B8': array([43., 44., 44., ..., 45., 49., 57.]),
#    'Matrix_Air_B9': array([43., 44., 41., ..., 46., 48., 56.]),
#    'Matrix_Air_F3': array([42., 43., 44., ..., 44., 47., 52.]),
#    'Matrix_Air_F2': array([43., 48., 44., ..., 46., 48., 57.]),
#    'Matrix_Air_F1': array([41., 43., 42., ..., 46., 46., 58.]),
#    'Matrix_Air_F5': array([43., 43., 44., ..., 44., 46., 51.]),
#    'Matrix_Air_F4': array([42., 43., 44., ..., 44., 46., 52.]),
#    'Matrix_Air_F6': array([47., 45., 44., ..., 46., 46., 50.]),
#    'Matrix_Air_F7': array([49., 46., 45., ..., 45., 47., 49.]),
#    'Matrix_Air_E6': array([47., 49., 49., ..., 45., 46., 47.]),
#    'Matrix_Air_D2': array([43., 43., 43., ..., 48., 46., 48.]),
#    'Matrix_Air_D3': array([43., 48., 44., ..., 46., 50., 49.]),
#    'Matrix_Air_D1': array([44., 43., 44., ..., 65., 48., 57.]),
#    'Matrix_Air_E5': array([45., 45., 45., ..., 46., 51., 55.]),
#    'Matrix_Air_E4': array([43., 43., 44., ..., 44., 47., 54.]),
#    'Matrix_Air_E1': array([44., 46., 45., ..., 43., 48., 59.]),
#    'Matrix_Air_E3': array([43., 43., 44., ..., 45., 46., 53.]),
#    'Matrix_Air_B10': array([43., 48., 44., ..., 44., 47., 58.]),
#    'Matrix_Air_E2': array([46., 46., 47., ..., 44., 51., 60.]),
#    'Matrix_Air_B1': array([ 47.,  57., 143., ...,  45.,  46.,  58.]),
#    'Matrix_Air_B2': array([44., 42., 44., ..., 45., 47., 56.]),
#    'Matrix_Air_B3': array([44., 42., 44., ..., 44., 56., 62.]),
#    'Matrix_Air_B7': array([44., 43., 43., ..., 51., 48., 57.]),
#    'Matrix_Air_C3': array([43., 44., 44., ..., 47., 49., 57.]),
#    'Matrix_Air_C2': array([43., 44., 44., ..., 48., 48., 62.]),
#    'Matrix_Air_B6': array([42., 44., 45., ..., 46., 46., 55.]),
#    'Matrix_Air_B4': array([44., 44., 43., ..., 50., 47., 52.]),
#    'Matrix_Air_B5': array([46., 44., 44., ..., 60., 55., 59.]),
#    'Matrix_Air_C1': array([50., 47., 46., ..., 45., 47., 63.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([43., 43., 45., ..., 50., 50., 49.]),
#    'Matrix_Sponge_B2': array([44., 47., 45., ..., 45., 47., 45.]),
#    'Matrix_Sponge_B10': array([42., 45., 49., ..., 44., 48., 44.]),
#    'Matrix_Sponge_B1': array([ 45., 132., 353., ...,  46.,  46.,  46.]),
#    'Matrix_Sponge_B5': array([44., 44., 43., ..., 75., 47., 47.]),
#    'Matrix_Sponge_C1': array([44., 44., 43., ..., 43., 43., 44.]),
#    'Matrix_Sponge_B4': array([43., 44., 42., ..., 41., 45., 48.]),
#    'Matrix_Sponge_C2': array([43., 42., 44., ..., 45., 47., 44.]),
#    'Matrix_Sponge_B6': array([44., 42., 44., ..., 44., 45., 44.]),
#    'Matrix_Sponge_B7': array([43., 45., 47., ..., 46., 42., 44.]),
#    'Matrix_Sponge_C3': array([42., 48., 44., ..., 46., 43., 44.]),
#    'Matrix_Sponge_E4': array([42., 43., 44., ..., 44., 48., 45.]),
#    'Matrix_Sponge_D1': array([42., 43., 43., ..., 58., 45., 44.]),
#    'Matrix_Sponge_E5': array([44., 44., 46., ..., 45., 44., 44.]),
#    'Matrix_Sponge_D3': array([43., 44., 44., ..., 48., 49., 44.]),
#    'Matrix_Sponge_E6': array([44., 44., 44., ..., 45., 42., 44.]),
#    'Matrix_Sponge_D2': array([49., 43., 43., ..., 47., 47., 44.]),
#    'Matrix_Sponge_E2': array([44., 44., 46., ..., 44., 46., 44.]),
#    'Matrix_Sponge_E3': array([42., 44., 43., ..., 44., 49., 46.]),
#    'Matrix_Sponge_E1': array([43., 45., 46., ..., 44., 43., 44.]),
#    'Matrix_Sponge_F1': array([43., 48., 46., ..., 44., 44., 44.]),
#    'Matrix_Sponge_F2': array([43., 45., 43., ..., 44., 45., 46.]),
#    'Matrix_Sponge_F3': array([41., 44., 50., ..., 42., 44., 50.]),
#    'Matrix_Sponge_F7': array([43., 44., 46., ..., 49., 46., 44.]),
#    'Matrix_Sponge_F6': array([44., 44., 45., ..., 45., 50., 45.]),
#    'Matrix_Sponge_F4': array([43., 44., 45., ..., 44., 43., 44.]),
#    'Matrix_Sponge_F5': array([43., 45., 43., ..., 44., 45., 45.]),
#    'Matrix_Sponge_B9': array([46., 46., 46., ..., 44., 42., 44.]),
#    'Matrix_Sponge_B8': array([41., 42., 45., ..., 43., 43., 44.])}},
#  'S3': {'Air_Mat': {'Matrix_Air_B8': array([48., 42., 44., ..., 50., 56., 72.]),
#    'Matrix_Air_B9': array([43., 43., 43., ..., 54., 55., 69.]),
#    'Matrix_Air_F3': array([49., 45., 44., ..., 49., 51., 50.]),
#    'Matrix_Air_F2': array([50., 44., 43., ..., 49., 53., 51.]),
#    'Matrix_Air_F1': array([45., 43., 44., ..., 48., 53., 51.]),
#    'Matrix_Air_F5': array([48., 45., 43., ..., 46., 49., 51.]),
#    'Matrix_Air_G1': array([84., 48., 44., ..., 51., 45., 49.]),
#    'Matrix_Air_F4': array([52., 54., 44., ..., 54., 49., 51.]),
#    'Matrix_Air_G2': array([56., 43., 43., ..., 56., 55., 55.]),
#    'Matrix_Air_F6': array([68., 46., 43., ..., 45., 49., 54.]),
#    'Matrix_Air_F7': array([47., 46., 44., ..., 46., 48., 50.]),
#    'Matrix_Air_G3': array([46., 45., 43., ..., 52., 51., 58.]),
#    'Matrix_Air_E6': array([44., 43., 44., ..., 52., 56., 53.]),
#    'Matrix_Air_D2': array([44., 43., 44., ..., 47., 49., 62.]),
#    'Matrix_Air_D3': array([49., 44., 42., ..., 51., 50., 55.]),
#    'Matrix_Air_D1': array([50., 44., 44., ..., 48., 53., 69.]),
#    'Matrix_Air_E5': array([95., 58., 48., ..., 46., 56., 57.]),
#    'Matrix_Air_E4': array([46., 43., 42., ..., 50., 53., 48.]),
#    'Matrix_Air_E1': array([44., 43., 43., ..., 46., 46., 66.]),
#    'Matrix_Air_E3': array([44., 43., 44., ..., 48., 52., 56.]),
#    'Matrix_Air_B10': array([45., 42., 43., ..., 47., 57., 69.]),
#    'Matrix_Air_E2': array([46., 43., 44., ..., 46., 47., 63.]),
#    'Matrix_Air_B1': array([45., 42., 43., ..., 47., 55., 68.]),
#    'Matrix_Air_B2': array([49., 42., 43., ..., 50., 56., 65.]),
#    'Matrix_Air_B3': array([48., 43., 44., ..., 47., 58., 59.]),
#    'Matrix_Air_B7': array([44., 43., 44., ..., 56., 57., 71.]),
#    'Matrix_Air_C3': array([43., 45., 45., ..., 49., 49., 54.]),
#    'Matrix_Air_C2': array([44., 43., 44., ..., 48., 48., 55.]),
#    'Matrix_Air_B6': array([44., 42., 43., ..., 53., 53., 63.]),
#    'Matrix_Air_B4': array([45., 42., 44., ..., 48., 47., 63.]),
#    'Matrix_Air_B5': array([45., 44., 43., ..., 51., 54., 69.]),
#    'Matrix_Air_C1': array([57., 46., 47., ..., 47., 46., 57.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([43., 43., 44., ..., 49., 52., 51.]),
#    'Matrix_Sponge_B2': array([43., 44., 44., ..., 42., 44., 49.]),
#    'Matrix_Sponge_B10': array([42., 43., 45., ..., 45., 45., 46.]),
#    'Matrix_Sponge_B1': array([44., 44., 43., ..., 45., 44., 44.]),
#    'Matrix_Sponge_B5': array([44., 42., 46., ..., 53., 54., 48.]),
#    'Matrix_Sponge_C1': array([53., 51., 47., ..., 49., 44., 43.]),
#    'Matrix_Sponge_B4': array([43., 43., 44., ..., 44., 43., 44.]),
#    'Matrix_Sponge_C2': array([42., 43., 44., ..., 43., 44., 41.]),
#    'Matrix_Sponge_B6': array([44., 44., 44., ..., 44., 42., 44.]),
#    'Matrix_Sponge_B7': array([45., 44., 42., ..., 43., 44., 45.]),
#    'Matrix_Sponge_C3': array([43., 44., 44., ..., 44., 42., 43.]),
#    'Matrix_Sponge_E4': array([43., 42., 43., ..., 52., 54., 55.]),
#    'Matrix_Sponge_D1': array([43., 45., 43., ..., 50., 49., 46.]),
#    'Matrix_Sponge_E5': array([44., 42., 46., ..., 44., 49., 46.]),
#    'Matrix_Sponge_D3': array([44., 44., 44., ..., 43., 45., 41.]),
#    'Matrix_Sponge_E6': array([43., 43., 46., ..., 45., 46., 44.]),
#    'Matrix_Sponge_D2': array([43., 44., 45., ..., 44., 42., 43.]),
#    'Matrix_Sponge_E2': array([46., 44., 47., ..., 47., 46., 46.]),
#    'Matrix_Sponge_E3': array([42., 43., 44., ..., 47., 46., 52.]),
#    'Matrix_Sponge_E1': array([42., 44., 46., ..., 43., 45., 49.]),
#    'Matrix_Sponge_F1': array([44., 43., 44., ..., 42., 44., 47.]),
#    'Matrix_Sponge_F2': array([50., 43., 43., ..., 43., 44., 46.]),
#    'Matrix_Sponge_F3': array([43., 43., 44., ..., 44., 44., 48.]),
#    'Matrix_Sponge_F7': array([44., 43., 43., ..., 42., 45., 56.]),
#    'Matrix_Sponge_F6': array([41., 42., 44., ..., 43., 46., 54.]),
#    'Matrix_Sponge_F4': array([44., 48., 44., ..., 48., 44., 50.]),
#    'Matrix_Sponge_F5': array([44., 43., 44., ..., 43., 44., 55.]),
#    'Matrix_Sponge_B9': array([42., 43., 44., ..., 42., 44., 43.]),
#    'Matrix_Sponge_B8': array([45., 44., 44., ..., 42., 44., 44.])}},
#  'S4': {'Air_Mat': {'Matrix_Air_B8': array([43., 42., 44., ..., 54., 60., 95.]),
#    'Matrix_Air_B9': array([43., 43., 49., ..., 60., 56., 85.]),
#    'Matrix_Air_F3': array([45., 47., 46., ..., 55., 58., 99.]),
#    'Matrix_Air_F2': array([ 43.,  46.,  44., ...,  54.,  63., 106.]),
#    'Matrix_Air_F1': array([ 44.,  46.,  46., ...,  58.,  63., 100.]),
#    'Matrix_Air_F5': array([43., 44., 44., ..., 52., 65., 99.]),
#    'Matrix_Air_F4': array([44., 45., 45., ..., 51., 60., 98.]),
#    'Matrix_Air_F6': array([47., 47., 48., ..., 48., 59., 86.]),
#    'Matrix_Air_F7': array([46., 47., 47., ..., 49., 46., 48.]),
#    'Matrix_Air_E6': array([45., 47., 46., ..., 54., 59., 88.]),
#    'Matrix_Air_D2': array([42., 48., 44., ..., 60., 60., 76.]),
#    'Matrix_Air_D3': array([42., 46., 45., ..., 67., 59., 77.]),
#    'Matrix_Air_D1': array([43., 43., 42., ..., 58., 58., 92.]),
#    'Matrix_Air_E5': array([46., 47., 50., ..., 53., 58., 82.]),
#    'Matrix_Air_E4': array([ 44.,  48.,  44., ...,  61.,  63., 103.]),
#    'Matrix_Air_E1': array([44., 46., 48., ..., 51., 58., 80.]),
#    'Matrix_Air_E3': array([44., 44., 45., ..., 55., 60., 97.]),
#    'Matrix_Air_B10': array([43., 43., 44., ..., 56., 57., 91.]),
#    'Matrix_Air_E2': array([47., 50., 51., ..., 51., 61., 84.]),
#    'Matrix_Air_B1': array([ 62., 100.,  61., ...,  57.,  54.,  73.]),
#    'Matrix_Air_B2': array([46., 44., 45., ..., 50., 57., 73.]),
#    'Matrix_Air_B3': array([44., 44., 44., ..., 52., 60., 71.]),
#    'Matrix_Air_B7': array([43., 42., 44., ..., 56., 56., 81.]),
#    'Matrix_Air_C3': array([42., 46., 44., ..., 63., 61., 89.]),
#    'Matrix_Air_C2': array([41., 44., 44., ..., 56., 60., 87.]),
#    'Matrix_Air_B6': array([42., 43., 45., ..., 52., 57., 86.]),
#    'Matrix_Air_B4': array([43., 46., 45., ..., 55., 57., 71.]),
#    'Matrix_Air_B5': array([55., 46., 44., ..., 55., 53., 80.]),
#    'Matrix_Air_C1': array([44., 46., 66., ..., 56., 59., 88.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([42., 43., 43., ..., 49., 44., 46.]),
#    'Matrix_Sponge_B2': array([43., 44., 44., ..., 43., 44., 43.]),
#    'Matrix_Sponge_B10': array([42., 43., 44., ..., 46., 48., 45.]),
#    'Matrix_Sponge_B1': array([43., 43., 48., ..., 43., 43., 44.]),
#    'Matrix_Sponge_B5': array([44., 44., 44., ..., 76., 49., 45.]),
#    'Matrix_Sponge_C1': array([44., 46., 46., ..., 46., 42., 43.]),
#    'Matrix_Sponge_B4': array([43., 46., 44., ..., 48., 45., 43.]),
#    'Matrix_Sponge_C2': array([43., 48., 45., ..., 44., 41., 44.]),
#    'Matrix_Sponge_B6': array([48., 44., 44., ..., 44., 43., 44.]),
#    'Matrix_Sponge_B7': array([43., 47., 45., ..., 66., 45., 44.]),
#    'Matrix_Sponge_C3': array([42., 44., 44., ..., 44., 44., 45.]),
#    'Matrix_Sponge_E4': array([42., 42., 43., ..., 53., 51., 48.]),
#    'Matrix_Sponge_D1': array([44., 43., 45., ..., 88., 56., 50.]),
#    'Matrix_Sponge_E5': array([41., 43., 43., ..., 43., 44., 46.]),
#    'Matrix_Sponge_D3': array([42., 45., 44., ..., 64., 49., 48.]),
#    'Matrix_Sponge_E6': array([43., 42., 44., ..., 44., 43., 44.]),
#    'Matrix_Sponge_D2': array([43., 42., 44., ..., 49., 48., 51.]),
#    'Matrix_Sponge_E2': array([43., 48., 44., ..., 43., 44., 44.]),
#    'Matrix_Sponge_E3': array([42., 43., 43., ..., 54., 46., 42.]),
#    'Matrix_Sponge_E1': array([43., 43., 44., ..., 44., 44., 44.]),
#    'Matrix_Sponge_F1': array([48., 44., 43., ..., 45., 47., 44.]),
#    'Matrix_Sponge_F2': array([46., 43., 44., ..., 44., 45., 45.]),
#    'Matrix_Sponge_F3': array([42., 41., 44., ..., 44., 44., 45.]),
#    'Matrix_Sponge_F7': array([41., 43., 44., ..., 44., 46., 44.]),
#    'Matrix_Sponge_F6': array([42., 43., 45., ..., 44., 50., 44.]),
#    'Matrix_Sponge_F4': array([42., 42., 44., ..., 44., 45., 46.]),
#    'Matrix_Sponge_F5': array([43., 42., 44., ..., 43., 45., 49.]),
#    'Matrix_Sponge_B9': array([43., 44., 45., ..., 78., 47., 45.]),
#    'Matrix_Sponge_B8': array([42., 43., 44., ..., 42., 45., 48.])}},
#  'S5': {'Air_Mat': {'Matrix_Air_B8': array([ 43.,  44.,  44., ...,  69.,  87., 107.]),
#    'Matrix_Air_B9': array([ 43.,  44.,  44., ...,  74.,  88., 106.]),
#    'Matrix_Air_F3': array([ 46.,  44.,  44., ...,  66.,  78., 127.]),
#    'Matrix_Air_F2': array([ 43.,  44.,  44., ...,  69.,  81., 119.]),
#    'Matrix_Air_F1': array([ 43.,  43.,  44., ...,  74.,  82., 114.]),
#    'Matrix_Air_F5': array([ 43.,  41.,  44., ...,  68.,  72., 116.]),
#    'Matrix_Air_F4': array([ 43.,  44.,  46., ...,  66.,  76., 119.]),
#    'Matrix_Air_F6': array([ 43.,  44.,  47., ...,  66.,  70., 121.]),
#    'Matrix_Air_F7': array([ 45.,  46.,  50., ...,  64.,  67., 122.]),
#    'Matrix_Air_E6': array([ 42.,  44.,  44., ...,  63.,  81., 115.]),
#    'Matrix_Air_D2': array([42., 44., 44., ..., 66., 84., 95.]),
#    'Matrix_Air_D3': array([43., 48., 44., ..., 69., 81., 97.]),
#    'Matrix_Air_D1': array([ 44.,  43.,  44., ...,  78.,  88., 101.]),
#    'Matrix_Air_E5': array([ 43.,  44.,  44., ...,  59.,  86., 105.]),
#    'Matrix_Air_E4': array([ 45.,  43.,  42., ...,  64.,  79., 118.]),
#    'Matrix_Air_E1': array([ 42.,  44.,  51., ...,  56.,  82., 103.]),
#    'Matrix_Air_E3': array([ 42.,  42.,  44., ...,  66.,  77., 110.]),
#    'Matrix_Air_B10': array([ 44.,  44.,  44., ...,  71.,  89., 109.]),
#    'Matrix_Air_E2': array([ 43.,  48.,  45., ...,  58.,  78., 104.]),
#    'Matrix_Air_B1': array([ 42.,  46.,  63., ...,  59.,  76., 105.]),
#    'Matrix_Air_B2': array([ 42.,  48.,  44., ...,  58.,  72., 105.]),
#    'Matrix_Air_B3': array([ 43.,  43.,  44., ...,  54.,  71., 103.]),
#    'Matrix_Air_B7': array([ 43.,  44.,  44., ...,  65.,  83., 110.]),
#    'Matrix_Air_C3': array([ 43.,  45.,  43., ...,  60.,  77., 101.]),
#    'Matrix_Air_C2': array([43., 42., 44., ..., 58., 75., 97.]),
#    'Matrix_Air_B6': array([ 43.,  43.,  44., ...,  63.,  85., 103.]),
#    'Matrix_Air_B4': array([ 43.,  44.,  44., ...,  64.,  80., 103.]),
#    'Matrix_Air_B5': array([46., 45., 62., ..., 73., 78., 93.]),
#    'Matrix_Air_C1': array([ 42.,  63., 187., ...,  65.,  82., 103.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([41., 44., 49., ..., 49., 49., 47.]),
#    'Matrix_Sponge_B2': array([44., 44., 46., ..., 44., 49., 44.]),
#    'Matrix_Sponge_B10': array([44., 43., 46., ..., 44., 49., 44.]),
#    'Matrix_Sponge_B1': array([ 65., 167., 127., ...,  43.,  46.,  46.]),
#    'Matrix_Sponge_B5': array([44., 47., 59., ..., 46., 45., 44.]),
#    'Matrix_Sponge_C1': array([42., 44., 45., ..., 44., 45., 44.]),
#    'Matrix_Sponge_B4': array([43., 43., 44., ..., 44., 43., 44.]),
#    'Matrix_Sponge_C2': array([43., 45., 44., ..., 46., 44., 42.]),
#    'Matrix_Sponge_B6': array([44., 42., 44., ..., 44., 45., 43.]),
#    'Matrix_Sponge_B7': array([43., 44., 44., ..., 44., 46., 44.]),
#    'Matrix_Sponge_C3': array([40., 44., 50., ..., 44., 41., 44.]),
#    'Matrix_Sponge_E4': array([43., 44., 46., ..., 45., 46., 42.]),
#    'Matrix_Sponge_D1': array([44., 43., 43., ..., 46., 44., 49.]),
#    'Matrix_Sponge_E5': array([43., 43., 44., ..., 44., 44., 45.]),
#    'Matrix_Sponge_D3': array([43., 47., 44., ..., 46., 47., 46.]),
#    'Matrix_Sponge_E6': array([42., 43., 42., ..., 44., 43., 44.]),
#    'Matrix_Sponge_D2': array([43., 44., 44., ..., 45., 45., 45.]),
#    'Matrix_Sponge_E2': array([42., 41., 45., ..., 42., 44., 49.]),
#    'Matrix_Sponge_E3': array([41., 43., 44., ..., 44., 44., 43.]),
#    'Matrix_Sponge_E1': array([43., 43., 44., ..., 44., 44., 44.]),
#    'Matrix_Sponge_F1': array([43., 48., 44., ..., 44., 42., 44.]),
#    'Matrix_Sponge_F2': array([42., 43., 44., ..., 42., 45., 48.]),
#    'Matrix_Sponge_F3': array([43., 42., 44., ..., 41., 44., 47.]),
#    'Matrix_Sponge_F7': array([45., 49., 50., ..., 44., 43., 44.]),
#    'Matrix_Sponge_F6': array([44., 46., 49., ..., 44., 42., 44.]),
#    'Matrix_Sponge_F4': array([47., 44., 44., ..., 44., 44., 44.]),
#    'Matrix_Sponge_F5': array([43., 44., 46., ..., 43., 43., 43.]),
#    'Matrix_Sponge_B9': array([43., 44., 45., ..., 44., 45., 43.]),
#    'Matrix_Sponge_B8': array([41., 43., 44., ..., 43., 44., 44.])}},
#  'S6': {'Air_Mat': {'Matrix_Air_B8': array([41., 44., 43., ..., 43., 45., 56.]),
#    'Matrix_Air_B9': array([46., 44., 44., ..., 43., 44., 55.]),
#    'Matrix_Air_F3': array([46., 43., 42., ..., 49., 48., 54.]),
#    'Matrix_Air_F2': array([47., 43., 42., ..., 48., 47., 53.]),
#    'Matrix_Air_F1': array([42., 43., 46., ..., 48., 46., 51.]),
#    'Matrix_Air_F5': array([44., 43., 42., ..., 46., 48., 50.]),
#    'Matrix_Air_F4': array([46., 43., 44., ..., 46., 46., 55.]),
#    'Matrix_Air_F6': array([73., 49., 45., ..., 45., 47., 46.]),
#    'Matrix_Air_F7': array([55., 58., 47., ..., 44., 45., 46.]),
#    'Matrix_Air_E6': array([46., 43., 43., ..., 50., 55., 66.]),
#    'Matrix_Air_D2': array([49., 43., 43., ..., 47., 45., 53.]),
#    'Matrix_Air_D3': array([54., 43., 44., ..., 47., 53., 47.]),
#    'Matrix_Air_D1': array([53., 43., 41., ..., 84., 70., 62.]),
#    'Matrix_Air_E5': array([48., 46., 44., ..., 45., 45., 49.]),
#    'Matrix_Air_E4': array([44., 45., 44., ..., 64., 61., 64.]),
#    'Matrix_Air_E1': array([47., 44., 44., ..., 44., 50., 51.]),
#    'Matrix_Air_E3': array([44., 42., 43., ..., 59., 55., 54.]),
#    'Matrix_Air_B10': array([42., 40., 44., ..., 43., 45., 55.]),
#    'Matrix_Air_E2': array([46., 44., 49., ..., 45., 45., 50.]),
#    'Matrix_Air_B1': array([51., 52., 94., ..., 43., 44., 44.]),
#    'Matrix_Air_B2': array([43., 44., 44., ..., 46., 43., 49.]),
#    'Matrix_Air_B3': array([49., 44., 44., ..., 50., 49., 56.]),
#    'Matrix_Air_B7': array([44., 44., 45., ..., 46., 49., 55.]),
#    'Matrix_Air_C3': array([54., 43., 45., ..., 43., 46., 46.]),
#    'Matrix_Air_C2': array([43., 45., 43., ..., 44., 44., 49.]),
#    'Matrix_Air_B6': array([47., 44., 43., ..., 48., 44., 52.]),
#    'Matrix_Air_B4': array([50., 44., 43., ..., 44., 46., 45.]),
#    'Matrix_Air_B5': array([43., 44., 44., ..., 71., 44., 51.]),
#    'Matrix_Air_C1': array([44., 46., 46., ..., 44., 46., 50.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([42., 43., 45., ..., 88., 62., 48.]),
#    'Matrix_Sponge_B2': array([41., 43., 43., ..., 51., 46., 46.]),
#    'Matrix_Sponge_B10': array([42., 43., 45., ..., 51., 46., 44.]),
#    'Matrix_Sponge_B1': array([58., 50., 43., ..., 44., 43., 44.]),
#    'Matrix_Sponge_B5': array([43., 45., 48., ..., 82., 86., 56.]),
#    'Matrix_Sponge_C1': array([43., 46., 50., ..., 47., 44., 42.]),
#    'Matrix_Sponge_B4': array([42., 41., 44., ..., 53., 45., 43.]),
#    'Matrix_Sponge_C2': array([45., 44., 42., ..., 44., 42., 43.]),
#    'Matrix_Sponge_B6': array([42., 43., 45., ..., 46., 49., 45.]),
#    'Matrix_Sponge_B7': array([42., 43., 44., ..., 70., 57., 49.]),
#    'Matrix_Sponge_C3': array([41., 43., 43., ..., 44., 43., 44.]),
#    'Matrix_Sponge_E4': array([42., 42., 43., ..., 70., 62., 59.]),
#    'Matrix_Sponge_D1': array([43., 41., 44., ..., 98., 82., 60.]),
#    'Matrix_Sponge_E5': array([42., 44., 45., ..., 45., 43., 45.]),
#    'Matrix_Sponge_D3': array([42., 43., 45., ..., 69., 52., 46.]),
#    'Matrix_Sponge_E6': array([43., 43., 43., ..., 51., 58., 52.]),
#    'Matrix_Sponge_D2': array([42., 43., 42., ..., 76., 60., 45.]),
#    'Matrix_Sponge_E2': array([43., 43., 43., ..., 46., 46., 45.]),
#    'Matrix_Sponge_E3': array([42., 43., 44., ..., 55., 53., 49.]),
#    'Matrix_Sponge_E1': array([47., 44., 44., ..., 44., 45., 45.]),
#    'Matrix_Sponge_F1': array([41., 44., 44., ..., 48., 45., 44.]),
#    'Matrix_Sponge_F2': array([43., 48., 45., ..., 51., 46., 47.]),
#    'Matrix_Sponge_F3': array([43., 46., 44., ..., 50., 44., 44.]),
#    'Matrix_Sponge_F7': array([42., 43., 43., ..., 49., 46., 44.]),
#    'Matrix_Sponge_F6': array([42., 43., 43., ..., 45., 45., 44.]),
#    'Matrix_Sponge_F4': array([43., 42., 44., ..., 43., 44., 48.]),
#    'Matrix_Sponge_F5': array([42., 44., 43., ..., 46., 42., 43.]),
#    'Matrix_Sponge_B9': array([43., 42., 44., ..., 66., 49., 44.]),
#    'Matrix_Sponge_B8': array([43., 46., 46., ..., 48., 43., 45.])}},
#  'S7': {'Air_Mat': {'Matrix_Air_B9': array([43., 47., 44., ..., 44., 47., 56.]),
#    'Matrix_Air_F3': array([42., 43., 45., ..., 44., 48., 57.]),
#    'Matrix_Air_F2': array([43., 49., 44., ..., 44., 48., 58.]),
#    'Matrix_Air_F5': array([49., 44., 44., ..., 44., 49., 64.]),
#    'Matrix_Air_F4': array([42., 44., 50., ..., 43., 54., 64.]),
#    'Matrix_Air_F6': array([42., 44., 46., ..., 43., 48., 64.]),
#    'Matrix_Air_F7': array([44., 45., 46., ..., 43., 46., 63.]),
#    'Matrix_Air_E6': array([43., 42., 44., ..., 44., 46., 59.]),
#    'Matrix_Air_D2': array([43., 43., 44., ..., 44., 47., 54.]),
#    'Matrix_Air_D3': array([43., 42., 44., ..., 44., 44., 53.]),
#    'Matrix_Air_D1': array([41., 43., 45., ..., 43., 47., 62.]),
#    'Matrix_Air_E5': array([42., 43., 41., ..., 43., 49., 61.]),
#    'Matrix_Air_E4': array([48., 43., 43., ..., 44., 47., 56.]),
#    'Matrix_Air_E1': array([41., 44., 49., ..., 43., 45., 56.]),
#    'Matrix_Air_E3': array([43., 46., 43., ..., 47., 50., 60.]),
#    'Matrix_Air_B10': array([42., 42., 44., ..., 42., 49., 56.]),
#    'Matrix_Air_E2': array([48., 44., 43., ..., 43., 45., 56.]),
#    'Matrix_Air_B1': array([67., 46., 49., ..., 43., 46., 51.]),
#    'Matrix_Air_B2': array([41., 43., 48., ..., 43., 50., 53.]),
#    'Matrix_Air_B3': array([42., 47., 44., ..., 42., 46., 49.]),
#    'Matrix_Air_B7': array([42., 43., 43., ..., 43., 50., 56.]),
#    'Matrix_Air_C3': array([42., 43., 44., ..., 44., 49., 56.]),
#    'Matrix_Air_C2': array([41., 43., 48., ..., 44., 50., 59.]),
#    'Matrix_Air_B6': array([42., 40., 44., ..., 44., 44., 57.]),
#    'Matrix_Air_B4': array([43., 44., 41., ..., 46., 46., 56.]),
#    'Matrix_Air_B5': array([130.,  52.,  46., ...,  44.,  44.,  56.]),
#    'Matrix_Air_C1': array([44., 69., 51., ..., 44., 47., 57.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([44., 46., 44., ..., 50., 44., 45.]),
#    'Matrix_Sponge_B2': array([43., 42., 43., ..., 49., 44., 44.]),
#    'Matrix_Sponge_B10': array([45., 43., 46., ..., 48., 43., 44.]),
#    'Matrix_Sponge_B1': array([42., 46., 46., ..., 46., 47., 44.]),
#    'Matrix_Sponge_B5': array([45., 43., 43., ..., 46., 43., 44.]),
#    'Matrix_Sponge_C1': array([42., 43., 44., ..., 47., 43., 45.]),
#    'Matrix_Sponge_B4': array([41., 43., 43., ..., 46., 44., 45.]),
#    'Matrix_Sponge_C2': array([42., 43., 41., ..., 52., 43., 44.]),
#    'Matrix_Sponge_B6': array([44., 43., 46., ..., 53., 45., 43.]),
#    'Matrix_Sponge_B7': array([43., 42., 44., ..., 58., 49., 45.]),
#    'Matrix_Sponge_C3': array([43., 43., 44., ..., 47., 44., 46.]),
#    'Matrix_Sponge_E4': array([40., 42., 48., ..., 46., 43., 44.]),
#    'Matrix_Sponge_D1': array([42., 42., 44., ..., 69., 59., 53.]),
#    'Matrix_Sponge_E5': array([43., 42., 43., ..., 46., 44., 42.]),
#    'Matrix_Sponge_D3': array([45., 44., 42., ..., 47., 48., 46.]),
#    'Matrix_Sponge_E6': array([42., 43., 42., ..., 48., 44., 50.]),
#    'Matrix_Sponge_D2': array([42., 44., 43., ..., 47., 44., 46.]),
#    'Matrix_Sponge_E2': array([43., 44., 44., ..., 46., 44., 44.]),
#    'Matrix_Sponge_E3': array([42., 43., 44., ..., 49., 50., 43.]),
#    'Matrix_Sponge_E1': array([44., 43., 42., ..., 43., 44., 42.]),
#    'Matrix_Sponge_F1': array([42., 43., 44., ..., 44., 44., 42.]),
#    'Matrix_Sponge_F2': array([47., 44., 42., ..., 44., 43., 44.]),
#    'Matrix_Sponge_F3': array([45., 43., 43., ..., 44., 42., 43.]),
#    'Matrix_Sponge_F7': array([43., 43., 44., ..., 43., 44., 49.]),
#    'Matrix_Sponge_F6': array([48., 44., 44., ..., 47., 44., 45.]),
#    'Matrix_Sponge_F4': array([43., 42., 44., ..., 44., 43., 45.]),
#    'Matrix_Sponge_F5': array([48., 44., 43., ..., 49., 45., 44.]),
#    'Matrix_Sponge_B9': array([43., 44., 42., ..., 47., 42., 43.]),
#    'Matrix_Sponge_B8': array([43., 43., 44., ..., 52., 45., 42.])}},
#  'S8': {'Air_Mat': {'Matrix_Air_B8': array([43., 42., 44., ..., 54., 60., 95.]),
#    'Matrix_Air_B9': array([43., 43., 49., ..., 60., 56., 85.]),
#    'Matrix_Air_F3': array([45., 47., 46., ..., 55., 58., 99.]),
#    'Matrix_Air_F2': array([ 43.,  46.,  44., ...,  54.,  63., 106.]),
#    'Matrix_Air_F1': array([ 44.,  46.,  46., ...,  58.,  63., 100.]),
#    'Matrix_Air_F5': array([43., 44., 44., ..., 52., 65., 99.]),
#    'Matrix_Air_F4': array([44., 45., 45., ..., 51., 60., 98.]),
#    'Matrix_Air_F6': array([47., 47., 48., ..., 48., 59., 86.]),
#    'Matrix_Air_F7': array([46., 47., 47., ..., 49., 46., 48.]),
#    'Matrix_Air_E6': array([45., 47., 46., ..., 54., 59., 88.]),
#    'Matrix_Air_D2': array([42., 48., 44., ..., 60., 60., 76.]),
#    'Matrix_Air_D3': array([42., 46., 45., ..., 67., 59., 77.]),
#    'Matrix_Air_D1': array([43., 43., 42., ..., 58., 58., 92.]),
#    'Matrix_Air_E5': array([46., 47., 50., ..., 53., 58., 82.]),
#    'Matrix_Air_E4': array([ 44.,  48.,  44., ...,  61.,  63., 103.]),
#    'Matrix_Air_E1': array([44., 46., 48., ..., 51., 58., 80.]),
#    'Matrix_Air_E3': array([44., 44., 45., ..., 55., 60., 97.]),
#    'Matrix_Air_B10': array([43., 43., 44., ..., 56., 57., 91.]),
#    'Matrix_Air_E2': array([47., 50., 51., ..., 51., 61., 84.]),
#    'Matrix_Air_B1': array([ 64., 103.,  61., ...,  57.,  54.,  73.]),
#    'Matrix_Air_B2': array([48., 44., 45., ..., 50., 57., 73.]),
#    'Matrix_Air_B3': array([46., 46., 46., ..., 52., 60., 71.]),
#    'Matrix_Air_B7': array([43., 42., 44., ..., 56., 56., 81.]),
#    'Matrix_Air_C3': array([42., 46., 44., ..., 63., 61., 89.]),
#    'Matrix_Air_C2': array([41., 44., 44., ..., 56., 60., 87.]),
#    'Matrix_Air_B6': array([42., 43., 45., ..., 52., 57., 86.]),
#    'Matrix_Air_B4': array([43., 46., 45., ..., 55., 57., 71.]),
#    'Matrix_Air_B5': array([55., 46., 44., ..., 55., 53., 80.]),
#    'Matrix_Air_C1': array([44., 46., 66., ..., 56., 59., 88.])},
#   'Sponge_Mat': {'Matrix_Sponge_B3': array([44., 43., 43., ..., 49., 44., 46.]),
#    'Matrix_Sponge_B2': array([43., 46., 46., ..., 43., 46., 43.]),
#    'Matrix_Sponge_B10': array([42., 43., 44., ..., 46., 48., 45.]),
#    'Matrix_Sponge_B1': array([46., 46., 50., ..., 46., 46., 44.]),
#    'Matrix_Sponge_B5': array([44., 44., 44., ..., 76., 49., 45.]),
#    'Matrix_Sponge_C1': array([44., 46., 46., ..., 46., 42., 43.]),
#    'Matrix_Sponge_B4': array([43., 46., 44., ..., 48., 45., 43.]),
#    'Matrix_Sponge_C2': array([43., 48., 45., ..., 44., 41., 44.]),
#    'Matrix_Sponge_B6': array([48., 44., 44., ..., 44., 43., 44.]),
#    'Matrix_Sponge_B7': array([43., 47., 45., ..., 66., 45., 44.]),
#    'Matrix_Sponge_C3': array([42., 44., 44., ..., 44., 44., 45.]),
#    'Matrix_Sponge_E4': array([42., 42., 43., ..., 53., 51., 48.]),
#    'Matrix_Sponge_D1': array([44., 43., 45., ..., 88., 56., 50.]),
#    'Matrix_Sponge_E5': array([41., 43., 43., ..., 43., 44., 46.]),
#    'Matrix_Sponge_D3': array([42., 45., 44., ..., 64., 49., 48.]),
#    'Matrix_Sponge_E6': array([43., 42., 44., ..., 44., 43., 44.]),
#    'Matrix_Sponge_D2': array([43., 42., 44., ..., 49., 48., 51.]),
#    'Matrix_Sponge_E2': array([43., 48., 44., ..., 43., 44., 44.]),
#    'Matrix_Sponge_E3': array([42., 43., 43., ..., 54., 46., 42.]),
#    'Matrix_Sponge_E1': array([43., 43., 44., ..., 44., 44., 44.]),
#    'Matrix_Sponge_F1': array([48., 44., 43., ..., 45., 47., 44.]),
#    'Matrix_Sponge_F2': array([46., 43., 44., ..., 44., 45., 45.]),
#    'Matrix_Sponge_F3': array([42., 41., 44., ..., 44., 44., 45.]),
#    'Matrix_Sponge_F7': array([41., 43., 44., ..., 44., 46., 44.]),
#    'Matrix_Sponge_F6': array([42., 43., 45., ..., 44., 50., 44.]),
#    'Matrix_Sponge_F4': array([42., 42., 44., ..., 44., 45., 46.]),
#    'Matrix_Sponge_F5': array([43., 42., 44., ..., 43., 45., 49.]),
#    'Matrix_Sponge_B9': array([43., 44., 45., ..., 78., 47., 45.]),
#    'Matrix_Sponge_B8': array([42., 43., 44., ..., 42., 45., 48.])}}}

# %% [markdown]
# Process data

# %%
test['S1'].keys()
# Out:
# dict_keys(['Air_Mat', 'Sponge_Mat'])

# %% [markdown]
# Only keep number starting at frame 3 because frame 1 and 2 include values way over 1000, which is past the range that sensor records.

# %%
d = test['S1']['Air_Mat']['Matrix_Air_B1']

d.reshape(-1, 27, 64).shape
# Out:
# (1, 27, 64)

# %%
d.shape
# Out:
# (1728,)

# %%
for index, i in enumerate():
    print(i, end=' ')
    if (index + 1) % 27 == 0:
        print("\n")
# Out:
# 44.0 44.0 50.0 47.0 47.0 49.0 47.0 47.0 48.0 50.0 46.0 49.0 44.0 43.0 43.0 42.0 42.0 43.0 44.0 41.0 44.0 47.0 44.0 44.0 43.0 42.0 44.0
#
# 46.0 41.0 48.0 52.0 58.0 62.0 57.0 54.0 60.0 58.0 49.0 48.0 42.0 43.0 48.0 44.0 42.0 42.0 44.0 44.0 43.0 43.0 45.0 43.0 45.0 44.0 42.0
#
# 44.0 44.0 50.0 47.0 52.0 61.0 55.0 55.0 69.0 64.0 49.0 47.0 45.0 46.0 44.0 44.0 43.0 43.0 46.0 41.0 43.0 44.0 43.0 43.0 43.0 44.0 46.0
#
# 44.0 50.0 48.0 46.0 49.0 55.0 59.0 50.0 131.0 103.0 47.0 46.0 46.0 43.0 42.0 44.0 41.0 44.0 43.0 46.0 42.0 43.0 43.0 42.0 44.0 42.0 43.0
#
# 52.0 65.0 75.0 73.0 79.0 386.0 487.0 102.0 603.0 393.0 67.0 59.0 51.0 46.0 48.0 49.0 46.0 45.0 44.0 47.0 43.0 44.0 45.0 44.0 45.0 46.0 45.0
#
# 48.0 58.0 67.0 63.0 100.0 488.0 244.0 79.0 159.0 265.0 68.0 54.0 48.0 46.0 45.0 46.0 44.0 44.0 43.0 44.0 45.0 44.0 45.0 42.0 44.0 47.0 46.0
#
# 44.0 47.0 44.0 45.0 49.0 69.0 52.0 45.0 53.0 66.0 48.0 44.0 43.0 43.0 44.0 41.0 42.0 43.0 42.0 43.0 44.0 42.0 44.0 43.0 43.0 46.0 44.0
#
# 42.0 46.0 44.0 46.0 56.0 53.0 46.0 48.0 44.0 47.0 48.0 43.0 43.0 43.0 42.0 44.0 42.0 42.0 43.0 42.0 43.0 43.0 43.0 44.0 42.0 43.0 46.0
#
# 44.0 46.0 50.0 77.0 115.0 62.0 58.0 47.0 48.0 68.0 90.0 46.0 45.0 44.0 44.0 49.0 43.0 44.0 43.0 44.0 44.0 42.0 43.0 43.0 43.0 44.0 42.0
#
# 44.0 46.0 51.0 89.0 97.0 51.0 52.0 46.0 49.0 69.0 127.0 50.0 44.0 45.0 47.0 44.0 42.0 42.0 46.0 43.0 44.0 43.0 42.0 43.0 43.0 44.0 45.0
#
# 43.0 46.0 47.0 73.0 60.0 45.0 47.0 45.0 44.0 48.0 69.0 47.0 45.0 44.0 44.0 44.0 42.0 42.0 43.0 43.0 46.0 44.0 42.0 42.0 42.0 43.0 44.0
#
# 51.0 56.0 94.0 207.0 98.0 51.0 54.0 51.0 49.0 56.0 85.0 54.0 47.0 42.0 44.0 50.0 43.0 44.0 46.0 43.0 43.0 43.0 42.0 43.0 44.0 42.0 44.0
#
# 56.0 85.0 231.0 350.0 232.0 71.0 63.0 64.0 67.0 117.0 230.0 145.0 52.0 44.0 46.0 47.0 45.0 45.0 44.0 44.0 46.0 44.0 43.0 44.0 43.0 44.0 45.0
#
# 47.0 62.0 126.0 145.0 86.0 52.0 52.0 50.0 54.0 96.0 164.0 122.0 49.0 44.0 45.0 45.0 44.0 47.0 44.0 44.0 44.0 42.0 43.0 43.0 43.0 44.0 42.0
#
# 44.0 60.0 118.0 95.0 73.0 46.0 48.0 53.0 49.0 67.0 86.0 65.0 46.0 44.0 44.0 44.0 42.0 43.0 42.0 43.0 44.0 42.0 44.0 48.0 43.0 43.0 43.0
#
# 52.0 139.0 268.0 167.0 173.0 68.0 61.0 66.0 76.0 152.0 136.0 135.0 63.0 46.0 45.0 47.0 45.0 44.0 42.0 44.0 42.0 44.0 48.0 44.0 44.0 44.0 43.0
#
# 56.0 155.0 285.0 164.0 172.0 66.0 58.0 64.0 76.0 134.0 132.0 125.0 62.0 46.0 46.0 46.0 47.0 44.0 43.0 42.0 44.0 44.0 44.0 43.0 46.0 44.0 44.0
#
# 44.0 56.0 90.0 66.0 55.0 47.0 43.0 47.0 52.0 61.0 64.0 65.0 46.0 44.0 44.0 43.0 45.0 42.0 43.0 41.0 44.0 41.0 44.0 48.0 43.0 43.0 44.0
#
# 46.0 73.0 148.0 98.0 56.0 50.0 49.0 47.0 51.0 59.0 63.0 53.0 47.0 43.0 44.0 44.0 42.0 43.0 44.0 41.0 44.0 47.0 44.0 43.0 44.0 43.0 44.0
#
# 48.0 63.0 122.0 109.0 56.0 51.0 48.0 51.0 54.0 57.0 71.0 60.0 51.0 44.0 44.0 43.0 43.0 43.0 44.0 43.0 44.0 46.0 44.0 42.0 43.0 43.0 44.0
#
# 46.0 44.0 56.0 54.0 45.0 43.0 44.0 43.0 44.0 46.0 48.0 46.0 48.0 43.0 44.0 43.0 42.0 43.0 43.0 44.0 42.0 43.0 48.0 43.0 42.0 43.0 44.0
#
# 41.0 46.0 62.0 53.0 44.0 44.0 43.0 44.0 44.0 45.0 48.0 48.0 44.0 44.0 44.0 42.0 43.0 43.0 47.0 41.0 43.0 44.0 42.0 43.0 46.0 43.0 44.0
#
# 46.0 63.0 130.0 87.0 57.0 53.0 51.0 50.0 51.0 56.0 79.0 54.0 47.0 44.0 42.0 44.0 43.0 43.0 43.0 47.0 42.0 43.0 44.0 43.0 44.0 45.0 44.0
#
# 46.0 62.0 100.0 89.0 56.0 49.0 51.0 49.0 51.0 67.0 108.0 63.0 52.0 44.0 44.0 44.0 44.0 43.0 42.0 47.0 42.0 43.0 44.0 44.0 44.0 46.0 44.0
#
# 43.0 52.0 73.0 58.0 48.0 47.0 46.0 46.0 48.0 60.0 90.0 69.0 46.0 44.0 44.0 42.0 41.0 43.0 43.0 43.0 44.0 42.0 44.0 44.0 43.0 45.0 44.0
#
# 61.0 162.0 231.0 151.0 78.0 62.0 57.0 62.0 69.0 94.0 110.0 87.0 52.0 45.0 46.0 44.0 42.0 43.0 44.0 44.0 45.0 43.0 44.0 46.0 43.0 44.0 44.0
#
# 112.0 272.0 384.0 293.0 165.0 98.0 86.0 91.0 148.0 195.0 204.0 180.0 92.0 49.0 45.0 52.0 46.0 44.0 45.0 44.0 45.0 44.0 44.0 45.0 46.0 45.0 47.0
#
# 77.0 157.0 222.0 199.0 113.0 74.0 70.0 76.0 114.0 161.0 180.0 180.0 99.0 47.0 46.0 50.0 45.0 44.0 44.0 44.0 45.0 43.0 44.0 44.0 44.0 44.0 46.0
#
# 62.0 87.0 119.0 121.0 72.0 56.0 54.0 58.0 74.0 84.0 84.0 79.0 55.0 46.0 46.0 46.0 44.0 42.0 49.0 44.0 44.0 43.0 42.0 43.0 44.0 43.0 44.0
#
# 84.0 133.0 123.0 125.0 98.0 61.0 58.0 66.0 78.0 83.0 82.0 81.0 71.0 48.0 47.0 46.0 44.0 44.0 50.0 44.0 44.0 43.0 42.0 43.0 44.0 43.0 45.0
#
# 87.0 168.0 183.0 166.0 116.0 71.0 67.0 89.0 97.0 104.0 102.0 100.0 100.0 59.0 46.0 49.0 49.0 44.0 44.0 44.0 43.0 43.0 44.0 43.0 44.0 42.0 45.0
#
# 85.0 213.0 236.0 167.0 116.0 88.0 97.0 136.0 149.0 150.0 128.0 126.0 98.0 61.0 47.0 50.0 50.0 44.0 44.0 44.0 43.0 44.0 44.0 44.0 44.0 44.0 46.0
#
# 86.0 161.0 191.0 153.0 105.0 84.0 91.0 157.0 157.0 168.0 140.0 118.0 67.0 49.0 47.0 50.0 46.0 49.0 44.0 44.0 45.0 42.0 44.0 43.0 44.0 45.0 44.0
#
# 167.0 379.0 409.0 320.0 172.0 137.0 172.0 271.0 226.0 241.0 204.0 188.0 129.0 60.0 51.0 58.0 50.0 43.0 46.0 49.0 45.0 45.0 45.0 43.0 45.0 45.0 46.0
#
# 113.0 188.0 211.0 249.0 168.0 146.0 196.0 276.0 217.0 214.0 180.0 174.0 133.0 70.0 46.0 56.0 48.0 46.0 43.0 46.0 43.0 45.0 48.0 44.0 44.0 44.0 45.0
#
# 82.0 136.0 168.0 202.0 203.0 190.0 248.0 249.0 247.0 212.0 165.0 150.0 82.0 49.0 50.0 54.0 48.0 46.0 45.0 43.0 44.0 45.0 40.0 45.0 48.0 45.0 46.0
#
# 83.0 130.0 160.0 168.0 174.0 131.0 152.0 163.0 154.0 131.0 106.0 85.0 68.0 47.0 48.0 50.0 48.0 44.0 45.0 41.0 44.0 44.0 43.0 44.0 45.0 42.0 46.0
#
# 95.0 227.0 217.0 202.0 210.0 129.0 162.0 169.0 162.0 131.0 114.0 95.0 72.0 52.0 48.0 53.0 49.0 45.0 46.0 44.0 45.0 44.0 48.0 44.0 43.0 44.0 45.0
#
# 69.0 129.0 159.0 158.0 137.0 112.0 136.0 143.0 137.0 132.0 120.0 95.0 67.0 46.0 46.0 50.0 46.0 42.0 45.0 47.0 45.0 45.0 44.0 42.0 44.0 44.0 45.0
#
# 59.0 81.0 108.0 138.0 134.0 127.0 149.0 156.0 129.0 114.0 90.0 70.0 58.0 46.0 46.0 50.0 45.0 44.0 44.0 44.0 45.0 44.0 44.0 44.0 44.0 43.0 45.0
#
# 75.0 117.0 165.0 217.0 234.0 240.0 258.0 247.0 241.0 212.0 140.0 78.0 61.0 48.0 50.0 58.0 50.0 45.0 48.0 43.0 45.0 45.0 42.0 44.0 49.0 45.0 47.0
#
# 66.0 95.0 112.0 143.0 163.0 132.0 139.0 216.0 194.0 180.0 142.0 71.0 57.0 50.0 47.0 54.0 49.0 46.0 44.0 48.0 43.0 44.0 45.0 44.0 44.0 44.0 47.0
#
# 57.0 73.0 84.0 106.0 134.0 111.0 100.0 182.0 150.0 141.0 100.0 60.0 50.0 46.0 46.0 50.0 48.0 45.0 44.0 49.0 43.0 44.0 44.0 42.0 44.0 49.0 45.0
#
# 53.0 59.0 65.0 89.0 98.0 82.0 71.0 115.0 97.0 93.0 63.0 57.0 47.0 44.0 45.0 46.0 43.0 43.0 43.0 44.0 45.0 42.0 44.0 46.0 44.0 44.0 44.0
#
# 69.0 66.0 73.0 109.0 133.0 106.0 78.0 133.0 110.0 103.0 68.0 56.0 50.0 47.0 48.0 59.0 49.0 44.0 43.0 44.0 44.0 41.0 44.0 47.0 44.0 44.0 46.0
#
# 102.0 72.0 84.0 130.0 155.0 143.0 86.0 150.0 138.0 124.0 76.0 60.0 53.0 48.0 56.0 237.0 129.0 44.0 44.0 43.0 45.0 44.0 44.0 44.0 47.0 44.0 48.0
#
# 58.0 69.0 76.0 118.0 144.0 118.0 81.0 126.0 129.0 108.0 72.0 56.0 52.0 48.0 62.0 68.0 52.0 43.0 44.0 43.0 44.0 43.0 43.0 44.0 42.0 44.0 48.0
#
# 87.0 98.0 121.0 187.0 275.0 251.0 138.0 214.0 196.0 149.0 97.0 73.0 62.0 50.0 72.0 104.0 56.0 46.0 50.0 45.0 45.0 44.0 43.0 44.0 44.0 44.0 47.0
#
# 135.0 161.0 225.0 297.0 423.0 421.0 292.0 356.0 318.0 304.0 172.0 106.0 69.0 57.0 88.0 193.0 85.0 50.0 50.0 46.0 46.0 45.0 44.0 45.0 46.0 46.0 49.0
#
# 83.0 100.0 142.0 189.0 217.0 214.0 161.0 179.0 171.0 136.0 102.0 77.0 58.0 52.0 60.0 72.0 49.0 46.0 45.0 49.0 45.0 44.0 44.0 43.0 44.0 45.0 46.0
#
# 56.0 76.0 110.0 111.0 104.0 120.0 89.0 90.0 91.0 77.0 70.0 64.0 52.0 45.0 52.0 60.0 48.0 44.0 43.0 44.0 43.0 43.0 44.0 43.0 44.0 46.0 46.0
#
# 110.0 320.0 356.0 325.0 202.0 190.0 179.0 170.0 160.0 145.0 140.0 131.0 89.0 52.0 63.0 67.0 50.0 50.0 45.0 45.0 46.0 43.0 45.0 45.0 44.0 46.0 50.0
#
# 136.0 368.0 382.0 438.0 267.0 214.0 219.0 212.0 202.0 177.0 184.0 186.0 135.0 60.0 67.0 67.0 52.0 50.0 46.0 46.0 46.0 44.0 45.0 45.0 44.0 47.0 51.0
#
# 94.0 197.0 254.0 285.0 231.0 171.0 148.0 142.0 137.0 128.0 123.0 107.0 78.0 53.0 50.0 57.0 47.0 46.0 42.0 46.0 46.0 44.0 47.0 44.0 44.0 45.0 46.0
#
# 196.0 387.0 340.0 385.0 403.0 326.0 197.0 186.0 197.0 207.0 184.0 143.0 85.0 58.0 55.0 66.0 53.0 47.0 42.0 47.0 51.0 45.0 46.0 45.0 44.0 46.0 48.0
#
# 202.0 307.0 287.0 273.0 333.0 458.0 247.0 208.0 209.0 232.0 198.0 165.0 104.0 61.0 56.0 68.0 53.0 47.0 46.0 42.0 47.0 49.0 45.0 46.0 45.0 45.0 49.0
#
# 98.0 104.0 104.0 116.0 165.0 187.0 138.0 121.0 126.0 113.0 111.0 84.0 62.0 50.0 51.0 53.0 46.0 45.0 42.0 44.0 48.0 44.0 45.0 44.0 42.0 44.0 46.0
#
# 95.0 96.0 85.0 87.0 115.0 106.0 93.0 90.0 96.0 83.0 74.0 69.0 53.0 46.0 46.0 48.0 45.0 42.0 44.0 48.0 44.0 44.0 44.0 42.0 44.0 44.0 52.0
#
# 166.0 168.0 146.0 137.0 164.0 178.0 192.0 168.0 153.0 122.0 97.0 82.0 73.0 56.0 54.0 57.0 49.0 46.0 45.0 44.0 46.0 48.0 44.0 45.0 44.0 44.0 52.0
#
# 208.0 223.0 177.0 177.0 218.0 245.0 268.0 230.0 198.0 166.0 123.0 104.0 80.0 66.0 64.0 68.0 59.0 49.0 51.0 46.0 46.0 45.0 42.0 45.0 49.0 46.0 52.0
#
# 123.0 122.0 112.0 108.0 125.0 129.0 152.0 143.0 120.0 95.0 83.0 72.0 59.0 53.0 53.0 59.0 59.0 51.0 45.0 49.0 45.0 45.0 44.0 44.0 42.0 46.0 61.0
#
# 62.0 76.0 79.0 76.0 74.0 81.0 89.0 86.0 72.0 65.0 63.0 59.0 52.0 49.0 50.0 53.0 51.0 48.0 44.0 47.0 46.0 44.0 44.0 41.0 44.0 50.0 52.0
#
# 108.0 141.0 122.0 135.0 132.0 146.0 139.0 132.0 108.0 87.0 88.0 80.0 59.0 55.0 60.0 74.0 69.0 68.0 48.0 50.0 48.0 47.0 44.0 44.0 45.0 47.0 52.0
#
# 155.0 200.0 200.0 206.0 222.0 264.0 254.0 216.0 159.0 138.0 123.0 104.0 77.0 68.0 67.0 87.0 84.0 66.0 59.0 62.0 51.0 47.0 46.0 46.0 48.0 47.0 57.0

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_pose_comparison(pose1_id='Matrix_Air_B1', pose2_id='Matrix_Air_B2', levels=15):
    all_frames_pose1, all_frames_pose2 = [], []

    # Collect frames for Pose 1
    if pose1_id in test['S1']['Air_Mat']:
        all_frames_pose1 = test['S1']['Air_Mat'][pose1_id]

    # Collect frames for Pose 2
    if pose2_id in test['S1']['Air_Mat']:
        all_frames_pose2 = test['S1']['Air_Mat'][pose2_id]

    if all_frames_pose1.size > 0 and all_frames_pose2.size > 0:
        # Reshape frames to 27x64
        frames_pose1 = all_frames_pose1.reshape(-1, 64, 27)
        frames_pose2 = all_frames_pose2.reshape(-1, 64, 27)

        print(f"Pose 1 frames shape: {frames_pose1.shape}")

        # Compute average pressure map for each posture
        avg_pose1 = np.mean(frames_pose1, axis=0)  # Mean over frames
        avg_pose2 = np.mean(frames_pose2, axis=0)  # Mean over frames

        # Find global min/max for consistent color scale
        vmin = min(avg_pose1.min(), avg_pose2.min())
        vmax = max(avg_pose1.max(), avg_pose2.max())

        # Generate identical contour levels
        contour_levels = np.linspace(vmin, vmax, levels)

        # Generate side-by-side contour plots
        fig, axes = plt.subplots(1, 2, figsize=(12, 12))

        # Contour Plot for Pose 1
        X, Y = np.meshgrid(np.arange(avg_pose1.shape[1]), np.arange(avg_pose1.shape[0]))
        contour1 = axes[0].contourf(X, Y, avg_pose1, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[0].set_title('Pose 1')
        axes[0].set_xlabel('Width')
        axes[0].set_ylabel('Height')
        axes[0].invert_yaxis()
        axes[0].tick_params(colors='white')

        # Contour Plot for Pose 2
        contour2 = axes[1].contourf(X, Y, avg_pose2, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[1].set_title('Pose 2')
        axes[1].set_xlabel('Width')
        axes[1].invert_yaxis()
        axes[1].tick_params(colors='white')

        # Common colorbar for both plots with white font
        cbar = fig.colorbar(contour2, ax=axes, orientation='vertical', fraction=0.02, pad=0.04)
        cbar.set_label('Pressure', color='white')
        cbar.ax.yaxis.set_tick_params(color='white')  # Change tick color
        plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')  # Change tick label color

        # Set white text for the entire figure
        plt.suptitle(f'Pressure Comparison: Posture {pose1_id} vs. Posture {pose2_id} (Same Contour Levels)', color='white')
        plt.tight_layout()
        plt.show()

plot_pose_comparison('Matrix_Air_F7', 'Matrix_Air_D1')
# Out:
# Pose 1 frames shape: (1, 64, 27)
# /var/folders/0y/gbwmzjp93k12t06yhk8_2p7h0000gn/T/ipykernel_84007/3104712315.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_single_pose(pose_id='Matrix_Air_B1', levels=15):
    all_frames_pose = []

    # Collect frames for the specified pose
    if pose_id in test['S1']['Air_Mat']:
        all_frames_pose = test['S1']['Air_Mat'][pose_id]

    if all_frames_pose.size > 0:
        # Reshape frames to 27x64
        frames_pose = all_frames_pose.reshape(-1, 64, 27)

        print(f"Pose frames shape: {frames_pose.shape}")

        # Compute average pressure map for the posture
        avg_pose = np.mean(frames_pose, axis=0)  # Mean over frames

        # Find min/max for color scale
        vmin = avg_pose.min()
        vmax = avg_pose.max()

        # Generate contour levels
        contour_levels = np.linspace(vmin, vmax, levels)

        # Generate contour plot
        fig, ax = plt.subplots(figsize=(6, 12))

        # Contour Plot for the Pose
        X, Y = np.meshgrid(np.arange(avg_pose.shape[1]), np.arange(avg_pose.shape[0]))
        contour = ax.contourf(X, Y, avg_pose, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        ax.set_title(f'Pose {pose_id}')
        ax.set_xlabel('Width')
        ax.set_ylabel('Height')
        ax.invert_yaxis()
        ax.tick_params(colors='white')

        # Colorbar for the plot with white font
        cbar = fig.colorbar(contour, ax=ax, orientation='vertical', fraction=0.02, pad=0.04)
        cbar.set_label('Pressure', color='white')
        cbar.ax.yaxis.set_tick_params(color='white')  # Change tick color
        plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')  # Change tick label color

        # Set white text for the entire figure
        plt.suptitle(f'Pressure Map: Posture {pose_id}', color='white')
        plt.tight_layout()
        plt.show()

plot_single_pose('Matrix_Air_F1')
# Out:
# Pose frames shape: (1, 64, 27)

# %%
info = pd.read_csv('../data/experiment-i/subject-info-i.csv')
info.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 info = pd.read_csv('../data/experiment-i/subject-info-i.csv')
#       2 info.head()
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/io/parsers/readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/io/parsers/readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:69, in CParserWrapper.__init__(self, src, **kwds)
#      67 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      68 try:
# ---> 69     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#      70 except Exception:
#      71     self.handles.close()
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:542, in pandas._libs.parsers.TextReader.__cinit__()
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:642, in pandas._libs.parsers.TextReader._get_header()
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:843, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File /opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1917, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
info['BMI'] =  info['Weight/kg'] / ((info['Height/cm'] / 100)**2)

def categorize_bmi(bmi):
    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi < 25:
        return "Normal weight"
    elif 25 <= bmi < 30:
        return "Overweight"
    else:
        return "Obesity"

# Apply the function to the BMI column
info['BMI Category'] = info['BMI'].apply(categorize_bmi)

# %%
info['Subject-Number'] = info['Subject-Number'].apply(lambda a: 'S' + str(a))
info
# Out:
#    Subject-Number  Age  Height/cm  Weight/kg        BMI   BMI Category
# 0              S1   19        175         87  28.408163     Overweight
# 1              S2   23        183         85  25.381469     Overweight
# 2              S3   23        183        100  29.860551     Overweight
# 3              S4   24        177         70  22.343516  Normal weight
# 4              S5   24        172         66  22.309356  Normal weight
# 5              S6   26        169         83  29.060607     Overweight
# 6              S7   27        179         96  29.961612     Overweight
# 7              S8   27        186         63  18.210198    Underweight
# 8              S9   30        174         74  24.441802  Normal weight
# 9             S10   30        174         79  26.093275     Overweight
# 10            S11   30        176         91  29.377583     Overweight
# 11            S12   33        170         78  26.989619     Overweight
# 12            S13   34        174         74  24.441802  Normal weight

# %%
overweight_subject = info[info['BMI Category'] == 'Overweight']['Subject-Number'].values
overweight_subject
# Out:
# array(['S1', 'S2', 'S3', 'S6', 'S7', 'S10', 'S11', 'S12'], dtype=object)

# %%
normal_kg_subject = info[info['BMI Category'] == 'Normal weight']['Subject-Number'].values
normal_kg_subject
# Out:
# array(['S4', 'S5', 'S9', 'S13'], dtype=object)

# %%
underweight_subject = info[info['BMI Category'] == 'Underweight']['Subject-Number'].values
underweight_subject
# Out:
# array(['S8'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_pose_comparison_by_BMI(pose, levels=15):
    """
    Plots a side-by-side contour map comparing the average pressure distribution 
    of a sleeping posture acorss different BMI categories.

    Parameters:
        poses (str): Posture identifier for the pose (default: '1')
        levels (int): Number of contour levels (default is 15)
    """
    overweight_frames, normal_frames = [], []

    # Collect frames for Overweight subjects
    for subject, postures in subject_posture_data.items():
        if pose in postures and subject in overweight_subject:
            overweight_frames.append(postures[pose])  # Shape: (num_frames, 32, 64)

    # Collect frames for Pose 2
    for subject, postures in subject_posture_data.items():
        if pose in postures and subject in normal_kg_subject:
            normal_frames.append(postures[pose])  # Shape: (num_frames, 32, 64)

    if overweight_frames and normal_frames:
        # Find minimum frame count across subjects for both category
        min_frames_overweight = min(f.shape[0] for f in overweight_frames)
        min_frames_normal = min(f.shape[0] for f in normal_frames)

        # Trim all subject data to have the same frame count
        trimmed_overweight = [f[:min_frames_overweight] for f in overweight_frames]
        trimmed_normal = [f[:min_frames_normal] for f in normal_frames]

        # Compute average pressure map for each posture
        avg_overweight = np.mean(np.array(trimmed_overweight), axis=(0, 1))  # Mean over subjects and frames
        avg_normal = np.mean(np.array(trimmed_normal), axis=(0, 1))  # Mean over subjects and frames

        # Find global min/max for consistent color scale
        vmin = min(avg_overweight.min(), avg_normal.min())
        vmax = max(avg_overweight.max(), avg_normal.max())

        # Generate identical contour levels
        contour_levels = np.linspace(vmin, vmax, levels)

        # Generate side-by-side contour plots
        fig, axes = plt.subplots(1, 2, figsize=(12, 12))

        # Contour Plot for Pose 1
        X, Y = np.meshgrid(np.arange(avg_overweight.shape[1]), np.arange(avg_overweight.shape[0]))
        contour1 = axes[0].contourf(X, Y, avg_overweight, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[0].set_title('Overweight Subjects')
        axes[0].set_xlabel('Width')
        axes[0].set_ylabel('Height')
        axes[0].invert_yaxis()
        axes[0].tick_params(colors='white')

        # Contour Plot for Pose 2
        contour2 = axes[1].contourf(X, Y, avg_normal, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[1].set_title(f'Normal Weight Subjects')
        axes[1].set_xlabel('Width')
        axes[1].invert_yaxis()
        axes[1].tick_params(colors='white')

        # Common colorbar for both plots with white font
        cbar = fig.colorbar(contour2, ax=axes, orientation='vertical', fraction=0.02, pad=0.04)
        cbar.set_label('Pressure', color='white')
        cbar.ax.yaxis.set_tick_params(color='white')  # Change tick color
        plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')  # Change tick label color

        # Set white text for the entire figure
        
        plt.tight_layout()
        plt.show()

# %%
plot_pose_comparison_by_BMI(pose = "1")
# Out:
# /var/folders/0y/gbwmzjp93k12t06yhk8_2p7h0000gn/T/ipykernel_63596/2794045859.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_pose_comparison_by_BMI(pose = "1")
# Out:
# /var/folders/0y/gbwmzjp93k12t06yhk8_2p7h0000gn/T/ipykernel_63596/2794045859.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
def plot_pose_comparison_overweight(pose1_id, pose2_id, levels=15):
    """
    Plots a side-by-side contour map comparing the average pressure distribution 
    of two postures with identical contour levels.

    Parameters:
        pose1_id (str): Posture identifier for the first pose 
        pose2_id (str): Posture identifier for the second pose 
        levels (int): Number of contour levels (default is 15)
    """
    
    all_frames_pose1, all_frames_pose2 = [], []

    # Collect frames for Pose 1
    for subject, postures in subject_posture_data.items():
        if pose1_id in postures and subject in overweight_subject:
            all_frames_pose1.append(postures[pose1_id])  # Shape: (num_frames, 32, 64)

    # Collect frames for Pose 2
    for subject, postures in subject_posture_data.items():
        if pose2_id in postures and subject in overweight_subject:
            all_frames_pose2.append(postures[pose2_id])  # Shape: (num_frames, 32, 64)

    if all_frames_pose1 and all_frames_pose2:
        # Find minimum frame count across subjects for both postures
        min_frames_pose1 = min(f.shape[0] for f in all_frames_pose1)
        min_frames_pose2 = min(f.shape[0] for f in all_frames_pose2)

        # Trim all subject data to have the same frame count
        trimmed_pose1 = [f[:min_frames_pose1] for f in all_frames_pose1]
        trimmed_pose2 = [f[:min_frames_pose2] for f in all_frames_pose2]

        # Compute average pressure map for each posture
        avg_pose1 = np.mean(np.array(trimmed_pose1), axis=(0, 1))  # Mean over subjects and frames
        avg_pose2 = np.mean(np.array(trimmed_pose2), axis=(0, 1))  # Mean over subjects and frames

        # Find global min/max for consistent color scale
        vmin = min(avg_pose1.min(), avg_pose2.min())
        vmax = max(avg_pose1.max(), avg_pose2.max())

        # Generate identical contour levels
        contour_levels = np.linspace(vmin, vmax, levels)

        # Generate side-by-side contour plots
        fig, axes = plt.subplots(1, 2, figsize=(12, 12))

        # Contour Plot for Pose 1
        X, Y = np.meshgrid(np.arange(avg_pose1.shape[1]), np.arange(avg_pose1.shape[0]))
        contour1 = axes[0].contourf(X, Y, avg_pose1, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[0].set_title('Sleeping on the Back')
        axes[0].set_xlabel('Width')
        axes[0].set_ylabel('Height')
        axes[0].invert_yaxis()
        axes[0].tick_params(colors='white')

        # Contour Plot for Pose 2
        contour2 = axes[1].contourf(X, Y, avg_pose2, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[1].set_title(f'Sleeping on the Left')
        axes[1].set_xlabel('Width')
        axes[1].invert_yaxis()
        axes[1].tick_params(colors='white')

        # Common colorbar for both plots with white font
        cbar = fig.colorbar(contour2, ax=axes, orientation='vertical', fraction=0.02, pad=0.04)
        cbar.set_label('Pressure', color='white')
        cbar.ax.yaxis.set_tick_params(color='white')  # Change tick color
        plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')  # Change tick label color

        # Set white text for the entire figure
        
        plt.suptitle(f'Pressure Comparison: Posture {pose1_id} vs. Posture {pose2_id} (Same Contour Levels)', color='white')
        plt.tight_layout()
        plt.show()

    else:
        print(f"Not enough data found for Posture {pose1_id} or Posture {pose2_id}.")

# %%
plot_pose_comparison_overweight(pose1_id="1", pose2_id="2")
# Out:
# /var/folders/0y/gbwmzjp93k12t06yhk8_2p7h0000gn/T/ipykernel_63596/3729560467.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
def plot_pose_comparison_normal(pose1_id, pose2_id, levels=15):
    """
    Plots a side-by-side contour map comparing the average pressure distribution 
    of two postures with identical contour levels.

    Parameters:
        pose1_id (str): Posture identifier for the first pose 
        pose2_id (str): Posture identifier for the second pose 
        levels (int): Number of contour levels (default is 15)
    """
    
    all_frames_pose1, all_frames_pose2 = [], []

    # Collect frames for Pose 1
    for subject, postures in subject_posture_data.items():
        if pose1_id in postures and subject in normal_kg_subject:
            all_frames_pose1.append(postures[pose1_id])  # Shape: (num_frames, 32, 64)

    # Collect frames for Pose 2
    for subject, postures in subject_posture_data.items():
        if pose2_id in postures and subject in normal_kg_subject:
            all_frames_pose2.append(postures[pose2_id])  # Shape: (num_frames, 32, 64)

    if all_frames_pose1 and all_frames_pose2:
        # Find minimum frame count across subjects for both postures
        min_frames_pose1 = min(f.shape[0] for f in all_frames_pose1)
        min_frames_pose2 = min(f.shape[0] for f in all_frames_pose2)

        # Trim all subject data to have the same frame count
        trimmed_pose1 = [f[:min_frames_pose1] for f in all_frames_pose1]
        trimmed_pose2 = [f[:min_frames_pose2] for f in all_frames_pose2]

        # Compute average pressure map for each posture
        avg_pose1 = np.mean(np.array(trimmed_pose1), axis=(0, 1))  # Mean over subjects and frames
        avg_pose2 = np.mean(np.array(trimmed_pose2), axis=(0, 1))  # Mean over subjects and frames

        # Find global min/max for consistent color scale
        vmin = min(avg_pose1.min(), avg_pose2.min())
        vmax = max(avg_pose1.max(), avg_pose2.max())

        # Generate identical contour levels
        contour_levels = np.linspace(vmin, vmax, levels)

        # Generate side-by-side contour plots
        fig, axes = plt.subplots(1, 2, figsize=(12, 12))

        # Contour Plot for Pose 1
        X, Y = np.meshgrid(np.arange(avg_pose1.shape[1]), np.arange(avg_pose1.shape[0]))
        contour1 = axes[0].contourf(X, Y, avg_pose1, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[0].set_title('Sleeping on the Back')
        axes[0].set_xlabel('Width')
        axes[0].set_ylabel('Height')
        axes[0].invert_yaxis()
        axes[0].tick_params(colors='white')

        # Contour Plot for Pose 2
        contour2 = axes[1].contourf(X, Y, avg_pose2, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        axes[1].set_title(f'Sleeping on the Left')
        axes[1].set_xlabel('Width')
        axes[1].invert_yaxis()
        axes[1].tick_params(colors='white')

        # Common colorbar for both plots with white font
        cbar = fig.colorbar(contour2, ax=axes, orientation='vertical', fraction=0.02, pad=0.04)
        cbar.set_label('Pressure', color='white')
        cbar.ax.yaxis.set_tick_params(color='white')  # Change tick color
        plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')  # Change tick label color

        # Set white text for the entire figure
        
        plt.suptitle(f'Pressure Comparison: Posture {pose1_id} vs. Posture {pose2_id} (Same Contour Levels)', color='white')
        plt.tight_layout()
        plt.show()

    else:
        print(f"Not enough data found for Posture {pose1_id} or Posture {pose2_id}.")

# %%
plot_pose_comparison_normal(pose1_id="1", pose2_id="2")
# Out:
# /var/folders/0y/gbwmzjp93k12t06yhk8_2p7h0000gn/T/ipykernel_63596/3705796783.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_pressure_difference_comparison(pose1_id="1", pose2_id="2", levels=15):
    """
    Computes and compares the pressure difference (last 10 - first 10 frames) 
    for two postures using side-by-side contour maps.

    Parameters:
        pose1_id (str): Posture identifier for the first pose (default: '1')
        pose2_id (str): Posture identifier for the second pose (default: '2')
        levels (int): Number of contour levels (default is 10)
    """
    all_frames_pose1, all_frames_pose2 = [], []

    # Collect frames for Posture 1
    for subject, postures in subject_posture_data.items():
        if pose1_id in postures and subject in overweight_subject:
            all_frames_pose1.append(postures[pose1_id])  # Shape: (num_frames, 32, 64)

    # Collect frames for Posture 2
    for subject, postures in subject_posture_data.items():
        if pose2_id in postures and subject in overweight_subject:
            all_frames_pose2.append(postures[pose2_id])  # Shape: (num_frames, 32, 64)

    if all_frames_pose1 and all_frames_pose2:
        # Find minimum frame count across subjects for both postures
        min_frames_pose1 = min(f.shape[0] for f in all_frames_pose1)
        min_frames_pose2 = min(f.shape[0] for f in all_frames_pose2)

     

        # Trim all subject data to have the same frame count
        trimmed_pose1 = [f[:min_frames_pose1] for f in all_frames_pose1]
        trimmed_pose2 = [f[:min_frames_pose2] for f in all_frames_pose2]

        # Compute average pressure per frame for each posture
        avg_pose1 = np.mean(np.array(trimmed_pose1), axis=0)  # Mean over subjects
        avg_pose2 = np.mean(np.array(trimmed_pose2), axis=0)  # Mean over subjects

        # Debugging: Print shapes
        print(f"Shape of avg_pose1: {avg_pose1.shape}, avg_pose2: {avg_pose2.shape}")

        # Ensure we slice along the correct axis (frames)
        if avg_pose1.shape[0] < 10 or avg_pose2.shape[0] < 10:
            print(f"Error: Not enough frames after averaging. Found {avg_pose1.shape[0]} frames.")
            return

        # Compute first and last 10-frame averages
        first_10_avg_pose1 = np.mean(avg_pose1[:20], axis=0)  # Shape: (32, 64)
        last_10_avg_pose1 = np.mean(avg_pose1[20:], axis=0)  # Shape: (32, 64)

        first_10_avg_pose2 = np.mean(avg_pose2[:20], axis=0)  # Shape: (32, 64)
        last_10_avg_pose2 = np.mean(avg_pose2[20:], axis=0)  # Shape: (32, 64)

        # Debugging: Print shapes
        print(f"Shape of first_10_avg_pose1: {first_10_avg_pose1.shape}, last_10_avg_pose1: {last_10_avg_pose1.shape}")
        print(f"Shape of first_10_avg_pose2: {first_10_avg_pose2.shape}, last_10_avg_pose2: {last_10_avg_pose2.shape}")

        # Compute the difference (last 10 - first 10) for each posture
        pressure_diff_pose1 = last_10_avg_pose1 - first_10_avg_pose1
        pressure_diff_pose2 = last_10_avg_pose2 - first_10_avg_pose2

        # Find global min/max for consistent color scale
        vmin = min(pressure_diff_pose1.min(), pressure_diff_pose2.min())
        vmax = max(pressure_diff_pose1.max(), pressure_diff_pose2.max())

        # Generate identical contour levels
        contour_levels = np.linspace(vmin, vmax, levels)

        # Generate side-by-side contour plots
        fig, axes = plt.subplots(1, 2, figsize=(12, 12))

        # Contour Plot for Posture 1
        X, Y = np.meshgrid(np.arange(pressure_diff_pose1.shape[1]), np.arange(pressure_diff_pose1.shape[0]))
        contour1 = axes[0].contourf(X, Y, pressure_diff_pose1, levels=contour_levels, cmap='RdBu_r', vmin=vmin, vmax=vmax)
        axes[0].set_title(f'Sleeping on the back')
        axes[0].set_xlabel('Width')
        axes[0].set_ylabel('Height')
        axes[0].invert_yaxis()

        # Contour Plot for Posture 2
        contour2 = axes[1].contourf(X, Y, pressure_diff_pose2, levels=contour_levels, cmap='RdBu_r', vmin=vmin, vmax=vmax)
        axes[1].set_title(f'Sleeping on the left')
        axes[1].set_xlabel('Width')
        axes[1].invert_yaxis()

        # Common colorbar for both plots
        cbar = fig.colorbar(contour2, ax=axes, orientation='vertical', fraction=0.02, pad=0.04)
        cbar.set_label('Pressure Change Over 20 Sec (mmHg)')

        plt.tight_layout()
        plt.show()

    else:
        print(f"Not enough data found for Posture {pose1_id} or Posture {pose2_id}.")

# %%
plot_pressure_difference_comparison(pose1_id="1", pose2_id="2")
# Out:
# /var/folders/0y/gbwmzjp93k12t06yhk8_2p7h0000gn/T/ipykernel_63596/806363226.py:92: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Shape of avg_pose1: (77, 64, 32), avg_pose2: (65, 64, 32)
# Shape of first_10_avg_pose1: (64, 32), last_10_avg_pose1: (64, 32)
# Shape of first_10_avg_pose2: (64, 32), last_10_avg_pose2: (64, 32)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_pose_comparison_all(pose1_id, pose2_id, levels=15):
    """
    Plots a 2x2 contour map comparing the average pressure distribution 
    of two postures for normal-weight and overweight subjects.

    Parameters:
        pose1_id (str): Posture identifier for the first pose.
        pose2_id (str): Posture identifier for the second pose.
        levels (int): Number of contour levels (default is 15).
    """
    
    def compute_average_pressure(pose_id, subject_group):
        """ Helper function to compute average pressure distribution for a given pose and subject group. """
        all_frames = [
            postures[pose_id] for subject, postures in subject_posture_data.items()
            if pose_id in postures and subject in subject_group
        ]
        
        if not all_frames:
            return None  # Not enough data
        
        min_frames = min(f.shape[0] for f in all_frames)
        trimmed_data = [f[:min_frames] for f in all_frames]
        return np.mean(np.array(trimmed_data), axis=(0, 1))  # Mean over subjects and frames

    # Compute average pressure maps
    avg_normal_pose1 = compute_average_pressure(pose1_id, normal_kg_subject)
    avg_normal_pose2 = compute_average_pressure(pose2_id, normal_kg_subject)
    avg_overweight_pose1 = compute_average_pressure(pose1_id, overweight_subject)
    avg_overweight_pose2 = compute_average_pressure(pose2_id, overweight_subject)

    # Determine global min/max pressure values for consistent contour levels
    vmin = min(avg_normal_pose1.min(), avg_normal_pose2.min(), avg_overweight_pose1.min(), avg_overweight_pose2.min())
    vmax = max(avg_normal_pose1.max(), avg_normal_pose2.max(), avg_overweight_pose1.max(), avg_overweight_pose2.max())
    contour_levels = np.linspace(vmin, vmax, levels)

    # Set up figure and axes (2x2 layout)
    fig, axes = plt.subplots(2, 2, figsize=(14, 28))
    
    # Meshgrid for contour plots
    X, Y = np.meshgrid(np.arange(avg_normal_pose1.shape[1]), np.arange(avg_normal_pose1.shape[0]))

    # Plot each contour
    plots = [
        (avg_normal_pose1, axes[0, 0], f'Normal Weight: Pose {pose1_id}'),
        (avg_normal_pose2, axes[0, 1], f'Normal Weight: Pose {pose2_id}'),
        (avg_overweight_pose1, axes[1, 0], f'Overweight: Pose {pose1_id}'),
        (avg_overweight_pose2, axes[1, 1], f'Overweight: Pose {pose2_id}')
    ]
    
    contours = []
    for avg_pressure, ax, title in plots:
        contour = ax.contourf(X, Y, avg_pressure, levels=contour_levels, cmap='RdGy_r', vmin=vmin, vmax=vmax)
        contours.append(contour)
        ax.set_title(title, fontsize=14, color='white')
        ax.set_xlabel('Width', fontsize=12, color='white')
        ax.set_ylabel('Height', fontsize=12, color='white')
        ax.invert_yaxis()
        ax.tick_params(colors='white')

    # Set white title for the figure
    plt.suptitle(f'Pressure Comparison: Normal vs. Overweight for Pose {pose1_id} and Pose {pose2_id}', color='white', fontsize=16)
    plt.tight_layout()
    plt.show()

    # Create separate figure for colorbar
    fig_cbar = plt.figure(figsize=(2, 6))  # Adjust size as needed
    cbar_ax = fig_cbar.add_axes([0.1, 0.1, 0.3, 0.8])  # Position of colorbar
    cbar = fig_cbar.colorbar(contours[0], cax=cbar_ax)  # Use one of the contour plots for colorbar
    cbar.set_label('Pressure (mmHg)', color='black')  # Set label color
    cbar.ax.yaxis.set_tick_params(color='black')
    plt.setp(cbar.ax.yaxis.get_ticklabels(), color='black')  # Set tick label color
    plt.show()  # Show separate colorbar

# %%
plot_pose_comparison_all(pose1_id="1", pose2_id="2", levels=15)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_only_colorbar(vmin, vmax, levels=15, cmap='RdGy_r'):
    """
    Plots only the colorbar without any contour plot.
    
    Parameters:
        vmin (float): Minimum pressure value.
        vmax (float): Maximum pressure value.
        levels (int): Number of contour levels.
        cmap (str): Colormap for the colorbar.
    """
    
    fig, ax = plt.subplots(figsize=(1.5, 6))  # Adjust figure size for a vertical colorbar
    
    # Create a dummy scalar mappable for the colorbar
    norm = plt.Normalize(vmin, vmax)
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])  # No data needed

    # Add the colorbar
    cbar = fig.colorbar(sm, cax=ax, orientation='vertical', ticks=np.linspace(vmin, vmax, levels))
    cbar.set_label('Pressure', color='white', fontsize=12)
    
    # Customize tick labels
    cbar.ax.yaxis.set_tick_params(color='black')
    plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')

    plt.show()

# Example Usage: Set vmin and vmax based on your data range
plot_only_colorbar(vmin=0, vmax=100)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the sleeping postures
sleeping_postures = ['Supsine', 'Right', 'Left', 'Right Fetus', 'Left Fetus']

# Generate random values for the average pressure on the head area
np.random.seed(0)  # For reproducibility
average_pressures = np.random.rand(len(sleeping_postures)) * 100  # Random values between 0 and 100

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(sleeping_postures, average_pressures, color='skyblue')
plt.xlabel('Sleeping Posture')
plt.ylabel('Average Pressure on Head Area (mmHg)')
plt.title('Average Pressure on Head Area for Different Sleeping Postures')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the sleeping postures
sleeping_postures = ['Supsine', 'Right', 'Left', 'Right Fetus', 'Left Fetus']

# Generate random values for the average pressure on the head area for both individuals
np.random.seed(0)  # For reproducibility
average_pressures_obese = np.random.rand(len(sleeping_postures)) * 100  # Random values between 0 and 100
average_pressures_non_obese = np.random.rand(len(sleeping_postures)) * 100  # Random values between 0 and 100

# Create the bar plot
x = np.arange(len(sleeping_postures))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width/2, average_pressures_obese, width, label='Obese', color=plt.cm.viridis(0.6))
bars2 = ax.bar(x + width/2, average_pressures_non_obese, width, label='Non-Obese', color=plt.cm.viridis(0.3))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Sleeping Posture')
ax.set_ylabel('Average Pressure on Head Area (mmHg)')
ax.set_title('Average Pressure on Head Area for Different Sleeping Postures')
ax.set_xticks(x)
ax.set_xticklabels(sleeping_postures)
ax.legend()

# Function to add labels on top of the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

fig.tight_layout()

plt.show()
